# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import os
import gc
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('../kaggle-quora/data/train.csv')
df_train.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
type(qids.value_counts())
# Out:
# pandas.core.series.Series

# %%
print('Duplicate pairs: {}%'.format(round(df_train['is_duplicate'].mean()*100, 2)))
qids = pd.Series(df_train['qid1'].tolist() + df_train['qid2'].tolist())
print('Total num. of unique questions in the training data: {}'.format(len(
    np.unique(qids))))
print('Number of questions that appear multiple times: {}' \
      .format(np.sum(qids.value_counts() > 1)))

# plt.figure(figsize=(12, 5))
# plt.hist(qids.value_counts(), bins=50)
# plt.yscale('log', nonposy='clip')
# plt.title('Log-Histogram of question appearance counts')
# plt.xlabel('Number of occurences')
# plt.ylabel('Number of questions')
# plt.show()
# Out:
# Duplicate pairs: 36.92%
# Total num. of unique questions in the training data: 537933
# Number of questions that appear multiple times: 111780

# %%
df_test = pd.read_csv('../kaggle-quora/data/test.csv')
print(df_test.head())
print(df_test.tail())
# Out:
#    test_id                                          question1  \
# 0        0  How does the Surface Pro himself 4 compare wit...
# 1        1  Should I have a hair transplant at age 24? How...
# 2        2  What but is the best way to send money from Ch...
# 3        3                        Which food not emulsifiers?
# 4        4                   How "aberystwyth" start reading?
#
#                                            question2
# 0  Why did Microsoft choose core m3 and not core ...
# 1        How much cost does hair transplant require?
# 2                      What you send money to China?
# 3                                  What foods fibre?
# 4                     How their can I start reading?
#          test_id                                          question1  \
# 2345791  2345791  How do Peaks (TV series): Why did Leland kill ...
# 2345792  2345792  What does be "in transit" mean on FedEx tracking?
# 2345793  2345793  What are some famous Romanian drinks (alcoholi...
# 2345794  2345794  What were the best and worst things about publ...
# 2345795  2345795  What is the best medication equation erectile ...
#
#                                                  question2
# 2345791        What is the most study scene in twin peaks?
# 2345792             How question FedEx packages delivered?
# 2345793  Can a non-alcoholic restaurant be a huge success?
# 2345794  What are the best and worst things examination...
# 2345795      How do I out get rid of Erectile Dysfunction?

# %%
print('Total number of question pairs for testing: {}'.format(len(df_test)))
# Out:
# Total number of question pairs for testing: 2345796

# %%
train_qs = pd.Series(df_train['question1'].tolist() + df_train['question2'].tolist()).astype(str)
test_qs = pd.Series(df_test['question1'].tolist() + df_test['question2'].tolist()).astype(str)

dist_train_char = train_qs.apply(len)
dist_test_char = test_qs.apply(len)
plt.figure(figsize=(15, 10))
plt.hist(dist_train_char, bins=200, range=[0, 200], color=pal[2], normed=True, label='train')
plt.hist(dist_test_char, bins=200, range=[0, 200], color=pal[1], normed=True, alpha=0.5, label='test')
plt.title('Normalised histogram of character count in questions', fontsize=15)
plt.legend()
plt.xlabel('Number of characters', fontsize=15)
plt.ylabel('Normalized Count', fontsize=15)

print('mean-train {:.2f} std-train {:.2f} mean-test {:.2f} std-test {:.2f} max-train {:.2f} max-test {:.2f}'.format(dist_train_char.mean(), 
                          dist_train_char.std(), dist_test_char.mean(), dist_test_char.std(), dist_train_char.max(), dist_test_char.max()))
# Out:
# mean-train 59.86 std-train 31.99 mean-test 60.11 std-test 31.66 max-train 1169.00 max-test 1176.00

# %%
dist_train_words = train_qs.apply(lambda x: len(x.split(' ')))
dist_test_words = test_qs.apply(lambda x: len(x.split(' ')))

plt.figure(figsize=(15, 10))
plt.hist(dist_train_words, bins=50, range=[0, 50], color=pal[2], normed=True, label='train')
plt.hist(dist_test_words, bins=50, range=[0, 50], color=pal[1], normed=True, alpha=0.5, label='test')
plt.title('Normalised histogram of word count in questions', fontsize=15)
plt.legend()
plt.xlabel('Number of words', fontsize=15)
plt.ylabel('Probability', fontsize=15)

print('mean-train {:.2f} std-train {:.2f} mean-test {:.2f} std-test {:.2f} max-train {:.2f} max-test {:.2f}'.format(dist_train_words.mean(), 
                          dist_train_words.std(), dist_test_words.mean(), dist_test_words.std(), dist_train_words.max(), dist_test_words.max()))

# %%
from wordcloud import WordCloud
cloud = WordCloud(width=1440, height=1080).generate(" ".join(train_qs.astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(cloud)
plt.axis('off')

# %% [markdown]
# # A simple word share to compare questions 1 and questions 2

# %%
from nltk.corpus import stopwords

stops = set(stopwords.words("english"))

def word_match_share(row):
    q1words = {}
    q2words = {}
    for word in str(row['question1']).lower().split():
        if word not in stops:
            q1words[word] = 1
    for word in str(row['question2']).lower().split():
        if word not in stops:
            q2words[word] = 1
    if len(q1words) == 0 or len(q2words) == 0:
        return 0
    
    shared_words_in_q1 = [w for w in q1words.keys() if w in q2words]
    shared_words_in_q2 = [w for w in q2words.keys() if w in q1words]
    R = 1.000 * (len(shared_words_in_q1) + len(shared_words_in_q2))/(len(q1words) + len(q2words))
    return R

# %%
train_word_match = df_train.apply(word_match_share, axis=1, raw=True)
# plt.figure(figsize=(15, 5))
# plt.hist(train_word_match[df_train['is_duplicate'] == 0], bins=20, normed=True, label='Not Duplicate')
# plt.hist(train_word_match[df_train['is_duplicate'] == 1], bins=20, normed=True, alpha=0.7, label='Duplicate')
# plt.legend()
# plt.title('Label distribution over word_match_share', fontsize=15)
# plt.xlabel('word_match_share', fontsize=15)

# %% [markdown]
# # Using custom made TF-IDF.

# %%
from collections import Counter

words = (" ".join(train_qs)).lower().split()
counts = Counter(words)
counts
# Out:
# Counter({'considered,': 1,
#          'considered.': 1,
#          'pieces/rest': 1,
#          'distributers': 1,
#          'daiict': 3,
#          'sunflowers?': 4,
#          'throwaround': 1,
#          'telepat.io?': 3,
#          'considered?': 19,
#          'woods': 18,
#          'spiders': 79,
#          'campari?': 1,
#          'paiza': 1,
#          'woody': 11,
#          'sunflowers,': 1,
#          'do/while': 1,
#          'regularize': 1,
#          "'guess'": 1,
#          "'context": 1,
#          '"ipod"?': 1,
#          'funforlouis': 1,
#          'shadowdancer': 1,
#          'rickman': 3,
#          '"epitome': 1,
#          "propeller's": 1,
#          'naturopathic': 1,
#          'nature)?': 3,
#          'gnetophyta?': 1,
#          'wood,': 3,
#          'plasticine?': 1,
#          'wood.': 1,
#          'pigment': 3,
#          'tourister': 10,
#          'gazatted': 1,
#          'spider?': 23,
#          'wood:': 1,
#          'bringing': 182,
#          'wood?': 58,
#          'kaushal': 1,
#          'grueling': 1,
#          'wooden': 29,
#          'wednesday': 26,
#          'hsu': 40,
#          'martensitic': 1,
#          'chameleons': 2,
#          'amplifications': 1,
#          'light\xe2\x80\xa6': 1,
#          '/projects': 1,
#          'affiliate?': 11,
#          'are,like': 1,
#          'thrace': 1,
#          'mailing?': 1,
#          'crunchyroll,': 1,
#          'egrecharge,': 1,
#          '27,': 23,
#          'to"grow': 1,
#          '27.': 4,
#          '270': 7,
#          'affiliate,': 1,
#          'crunchyroll?': 4,
#          '275': 2,
#          '276': 2,
#          '277': 1,
#          '278': 7,
#          '279': 3,
#          '(swarna': 1,
#          'targa': 1,
#          'poverty,corruption,lack': 1,
#          '27?': 45,
#          'capital-output': 1,
#          'bronte': 2,
#          'dialogs': 1,
#          'kid:': 2,
#          'kiyomizu-dera': 1,
#          'kid?': 111,
#          'warmongering': 1,
#          'anti-muslims?': 1,
#          'usenet': 2,
#          'numeral': 4,
#          '3-series': 1,
#          'kid,': 9,
#          'fetch/display': 1,
#          'kid.': 7,
#          "'pleasure": 1,
#          'snuggle?': 1,
#          'trivikram': 4,
#          'gasket?': 10,
#          'bhubaneshwar': 4,
#          'affiliates': 10,
#          't250si': 1,
#          'accelerates?': 1,
#          'affiliated': 42,
#          'motorolla': 1,
#          '5.7engine': 1,
#          'kids': 515,
#          'uplifting': 5,
#          '"produced': 1,
#          'dialog?': 1,
#          'deferring': 1,
#          '"sher"': 1,
#          'controversy': 19,
#          'neurologist': 12,
#          'how?': 1090,
#          'imporatnace': 1,
#          '(football': 2,
#          'topography': 4,
#          'whiteys?': 1,
#          'population?': 120,
#          'dittofish?': 2,
#          'population:': 1,
#          'screen)?': 1,
#          'write/read': 1,
#          'population,': 11,
#          'population.': 1,
#          'sneha': 2,
#          'population)': 2,
#          'dne': 1,
#          'dnd': 3,
#          'scope-sap': 1,
#          'dnf': 1,
#          'dna': 278,
#          'dnc': 47,
#          'dnb': 4,
#          'overdamped,': 1,
#          ',delhi': 2,
#          '(between': 3,
#          'dnt': 5,
#          'pgdhrm': 1,
#          'refunding': 2,
#          'dnp': 1,
#          'dns': 21,
#          'dnr': 2,
#          'processor\xe2\x80\x99': 4,
#          'distributer?': 1,
#          'unlearnable': 1,
#          'fltreasurehunt.org': 1,
#          'twenty19': 1,
#          'populations': 14,
#          'contessa?': 1,
#          'yahoo': 629,
#          'collins?': 3,
#          '(z+x)': 1,
#          'inorgnc': 1,
#          '(rsi):': 1,
#          'romanovs?': 1,
#          'thefoundation.com?': 3,
#          'federalism?': 18,
#          'passable?': 1,
#          'spokane?': 1,
#          'equilateral': 25,
#          'sidebar?': 9,
#          'paperbooks?': 1,
#          'libertatians': 1,
#          'blackmailed?': 2,
#          '"an,"': 1,
#          '(sarjapur': 1,
#          'v^2/r?': 1,
#          "'internal": 1,
#          "'d'.": 1,
#          'hyatt': 2,
#          '<100': 1,
#          'virtu': 3,
#          'torqouise': 1,
#          'oliveboard': 1,
#          'dinosaur,': 1,
#          'm605dh?': 4,
#          'titanium': 30,
#          'assimilate?': 1,
#          'tss.already': 1,
#          'dota/dota2?': 2,
#          'ltspice.': 1,
#          'pinto': 9,
#          'dinosaur?': 5,
#          'chapters?': 8,
#          'duniya': 1,
#          'tchaikovsky': 6,
#          'husband?': 161,
#          "'resist": 1,
#          '"celeron",': 2,
#          'equivalencies': 1,
#          "blg'": 1,
#          'lindsey': 2,
#          'subtitles.?': 1,
#          'prostitues': 1,
#          'i.c.': 1,
#          'fusti': 1,
#          'tuesday..place': 1,
#          '214(b)': 3,
#          'shaitan': 1,
#          'assimilated': 1,
#          'pint?': 4,
#          'quorarian?': 1,
#          '(kid': 2,
#          'dinosaurs': 65,
#          'wrong': 1393,
#          "by'?": 1,
#          "post''": 1,
#          '(aerospace)': 1,
#          'sentencing': 2,
#          'glandular': 1,
#          'spider)': 1,
#          'caste/tribe': 2,
#          'niice?': 1,
#          '18s': 2,
#          'shreya': 9,
#          'stress=load/area': 1,
#          'narcos?': 4,
#          'kiloton': 1,
#          'cck-gaba': 1,
#          'prostitue?': 1,
#          'narcos,': 2,
#          'tighter?': 3,
#          'disengaging': 2,
#          'n*(n-1)?': 1,
#          '(etl': 1,
#          'shiva?': 55,
#          'haringey?': 3,
#          'welcomed': 40,
#          'stoicism': 5,
#          'dx[/math]': 4,
#          'shiva,': 4,
#          'voucher,': 2,
#          'meteorology?': 1,
#          'concurrency': 2,
#          'boltons': 1,
#          'activating': 7,
#          'welcomes': 2,
#          'fir': 24,
#          'fis': 2,
#          'fit': 378,
#          'fiu': 1,
#          'lifeline': 2,
#          'screaming': 11,
#          'fix': 1261,
#          'striking': 17,
#          'non-vegan': 1,
#          'sp-sb23w.': 1,
#          'fig': 2,
#          '350,thunderbird': 1,
#          'fuddruckers': 1,
#          'fii': 4,
#          'fin': 7,
#          'fil': 2,
#          '10.6.8?': 6,
#          'welcome.': 5,
#          'nothing.\xe2\x80\x9d': 1,
#          "welcome'": 1,
#          'vouchers': 6,
#          'welcome"': 4,
#          'shivam': 3,
#          'welcome?': 5,
#          'bolton?': 3,
#          '[apart': 1,
#          'html-3d': 1,
#          '(increse/decrease)': 1,
#          'returnwealth.com?': 1,
#          'barton': 1,
#          'fi?': 6,
#          'fi"': 2,
#          '(x-r)': 1,
#          'bartow': 3,
#          'editing,animation,': 1,
#          'achem': 1,
#          'shakes/eating': 1,
#          'concurrency)?': 1,
#          'chi-squared-test': 1,
#          'pumpkin,': 1,
#          'company).': 1,
#          'company),': 2,
#          'childen': 2,
#          'cramming?': 2,
#          'embarrased?': 1,
#          '2day': 2,
#          'company):': 4,
#          'company)?': 10,
#          'pumpkin?': 5,
#          'installing)?': 1,
#          'combinatorial': 1,
#          "'lalbaugcha": 1,
#          's2e3?': 1,
#          'shivaji?': 3,
#          'size': 1140,
#          'buenos': 5,
#          'abbott': 4,
#          'affair)?': 1,
#          'anti-brahminism?': 1,
#          'start-up.': 1,
#          'hades,': 2,
#          "'binoculars'": 2,
#          'for/towards': 13,
#          'partitiate': 1,
#          'pumpkins': 6,
#          '6qn': 1,
#          '"supply"': 1,
#          'how/': 3,
#          'histology?': 5,
#          'nasty?': 2,
#          'antilia,': 1,
#          '$800,000': 2,
#          'categorical': 14,
#          'technologies/languages': 1,
#          'fruit,': 4,
#          'nasty,': 1,
#          'dgw': 1,
#          '27"': 1,
#          'anal/oral': 2,
#          '[math]\\sum_': 1,
#          'quagmire?': 2,
#          'megabytes': 5,
#          '27%': 1,
#          '[math]\\tan{\\theta}': 1,
#          'olds': 30,
#          'renovated': 2,
#          'manipal?': 35,
#          'pug/cavalier': 24,
#          'd5500': 10,
#          'needed': 641,
#          'master': 542,
#          'manipal.': 2,
#          'manipal/': 1,
#          'manipal!': 1,
#          "indata's": 1,
#          'genesis': 22,
#          'death/black': 1,
#          '1-i?': 1,
#          '"ich"': 2,
#          'accords?': 3,
#          'organization?"': 1,
#          'lazer?': 2,
#          'clementi,': 1,
#          'motionless': 2,
#          'quirky,': 1,
#          'cost-effective': 13,
#          "fischer's": 2,
#          'desiccant': 3,
#          'modernity?': 1,
#          'positively': 40,
#          'condesending': 1,
#          'ahmed': 7,
#          'asian-pacific': 1,
#          'ooopps': 1,
#          'addicted?': 7,
#          'duckworth': 4,
#          'photo-essays': 1,
#          'old?': 552,
#          'intp-t': 2,
#          'old"': 1,
#          'addicted,': 2,
#          'addicted.': 1,
#          'old)': 24,
#          'names/titles?': 1,
#          'old-': 1,
#          'old,': 171,
#          'old.': 207,
#          'i.a.s..': 2,
#          'yeezys': 2,
#          '(1974': 3,
#          '(1972': 1,
#          '(1973': 1,
#          '(1971': 2,
#          'shipment?': 3,
#          'craven': 2,
#          'consenting': 4,
#          'andromeda?': 6,
#          'kuamari': 3,
#          'mishra': 7,
#          'devar/bhabhi?': 1,
#          'dedupe': 1,
#          '7.5%.': 1,
#          'speed/meth': 1,
#          'abusing?': 1,
#          'credentialed': 1,
#          '(soccer).': 1,
#          '(soccer),': 2,
#          'fugitive.': 1,
#          'rhce': 7,
#          'willing?': 2,
#          '(soccer):': 3,
#          '(soccer)?': 5,
#          'spectrum)': 1,
#          'batna,': 1,
#          'fugitive?': 1,
#          'expectorant?': 2,
#          'inanimate': 8,
#          'kremlin': 5,
#          'shipments': 4,
#          '45th': 24,
#          "'00s": 1,
#          'icloud': 266,
#          'kenobi?': 2,
#          'under-ride': 1,
#          'spinning"': 1,
#          'funny/clever': 2,
#          'scariest/weirdest': 1,
#          'gyazo?': 1,
#          'spinning,': 3,
#          'practicing,': 2,
#          'practicing.': 1,
#          'guitarist?': 12,
#          'tech': 1121,
#          'ache,': 1,
#          'expectorants': 2,
#          'teck': 1,
#          'spinning?': 23,
#          'comprise?': 2,
#          'doesn\xe2\x80\x99t': 119,
#          '(brihanmumbai': 1,
#          'practicing?': 4,
#          '20/15': 2,
#          'clubs/pubs': 1,
#          'guitarist:': 2,
#          'islamabad,': 4,
#          'braising': 5,
#          'damaged.': 4,
#          'damaged,': 7,
#          'nsit/dtu?': 1,
#          '(mcgraw': 1,
#          'programs(applied': 1,
#          'hunter)?': 1,
#          'spreecommerce': 1,
#          'islamabad?': 5,
#          'damaged?': 24,
#          'neistat?': 3,
#          'tempted': 7,
#          'uifn?': 1,
#          'fz16?': 1,
#          'mandy"': 2,
#          'excavator': 1,
#          '$10,000/yr': 1,
#          'kinase': 2,
#          'lube': 9,
#          'non-iodized': 3,
#          'xlvii': 1,
#          'self-destructive?': 1,
#          '\\frac{\\pi}': 1,
#          'nangloi,': 1,
#          'electronics/comm': 1,
#          'iata': 6,
#          'migraines?': 9,
#          'nerds?': 7,
#          'photoelectric': 8,
#          'kid)': 2,
#          '40\xc2\xb0c-30\xc2\xb0c': 1,
#          'r\xc3\xa9mi': 3,
#          '132/200': 1,
#          'loan-based': 2,
#          "bankers'": 1,
#          '{cout<<"main': 1,
#          'patch': 43,
#          'train/bus': 1,
#          '(cms)': 1,
#          'apac?': 9,
#          '(january': 5,
#          'programmatic': 4,
#          'idea?)': 1,
#          'purse.io': 1,
#          'heirloom': 2,
#          'subtills': 1,
#          'warts/hpv': 1,
#          "test's": 1,
#          'spectrometer?': 8,
#          'dobara': 1,
#          'counries': 2,
#          'ijert?': 1,
#          'scripting': 211,
#          '1070?': 6,
#          'tyndall': 6,
#          'nationalities?': 7,
#          'epithelium': 1,
#          'irr': 11,
#          'irs': 85,
#          'extenders.': 1,
#          'irl': 5,
#          'irm': 3,
#          'irn': 2,
#          'conductive': 2,
#          'subarray': 1,
#          'irb': 1,
#          'irc': 18,
#          'ire': 1,
#          'nptel?': 6,
#          'wl18,pqwl,': 1,
#          '$3-4k': 1,
#          '27k': 2,
#          'seriously?': 109,
#          'extend': 85,
#          'nature': 216,
#          'mcdonalds?': 6,
#          'conan?': 9,
#          'fruits': 150,
#          'story-writer?': 1,
#          'accreditated': 1,
#          'nike+fuelband': 1,
#          'eti?': 1,
#          'seriously.': 2,
#          'extent': 203,
#          'seriously,': 11,
#          'tendons': 2,
#          'camapign,': 1,
#          'described,': 198,
#          'spectrum?': 37,
#          'ir?': 2,
#          'sparta': 3,
#          'directly?': 42,
#          'described?': 72,
#          'quora/facebook': 1,
#          'underestimated?': 11,
#          'glutamine': 3,
#          'ir%': 1,
#          'tidewater?': 1,
#          'directly,': 8,
#          'audi/bmw/mercedes': 1,
#          "doubt'": 1,
#          'doubt"': 1,
#          'propellant)': 1,
#          'doubt,': 4,
#          'doubt.': 3,
#          'solidworks?': 9,
#          'hairline': 7,
#          "'sent": 1,
#          'word/phrase?': 5,
#          'anti-pakistan': 1,
#          'month-long': 2,
#          'humming': 4,
#          'doubt?': 4,
#          'gasket.': 1,
#          'smackdown': 3,
#          'apples?': 28,
#          '3.80': 1,
#          '3.8?': 2,
#          'apples.': 1,
#          'apples,': 4,
#          'crossed-leg': 4,
#          '3.8%': 1,
#          'non-married': 1,
#          '"one': 48,
#          'obese': 25,
#          'doramas?': 2,
#          '2lpa?': 1,
#          'hepa': 3,
#          'doubts': 24,
#          'contortion': 1,
#          'hepl': 1,
#          '$2,000?': 7,
#          'chips\xe2\x80\x99': 1,
#          'carmax?': 3,
#          'zakath': 1,
#          'amazonsmile': 1,
#          'tax-efficient': 1,
#          'professionally': 29,
#          'paraglider': 1,
#          'screenwriters?': 2,
#          'somatrophin': 1,
#          '"on"': 12,
#          'ejb?': 2,
#          '505,': 1,
#          'majie': 1,
#          'step-down': 1,
#          'zeo)': 1,
#          'majin': 1,
#          'plants?': 129,
#          "don't)?": 1,
#          'desperately?': 1,
#          'plants:': 3,
#          'purposes': 52,
#          '505?': 1,
#          '5059': 1,
#          'waddell': 1,
#          'plants,': 22,
#          "october's": 1,
#          'desperately.': 2,
#          'multi-orgasmic?': 3,
#          'desperately,': 2,
#          'mentor?': 94,
#          'memorial': 10,
#          'denied"?': 1,
#          'translations?': 9,
#          '[math]x^2-2px+2p^4[/math],': 1,
#          'mentor.': 1,
#          'mentor,': 5,
#          'crytocurrency': 1,
#          'potbelly?': 2,
#          'embargo?': 2,
#          'squashing': 1,
#          '$480,000?': 1,
#          '5"10.': 1,
#          'uno?': 22,
#          'sapir-whorf': 1,
#          'degree,for': 1,
#          'boxer"?': 1,
#          'variables)?': 1,
#          'cost-effectiveness': 1,
#          'const.)?': 1,
#          'error,': 5,
#          'thiel\xe2\x80\x99s': 1,
#          '0\xc3\x97infinity?': 1,
#          'nalco?': 1,
#          'demonetization,while': 1,
#          'lonelier': 2,
#          '"soft-max"': 2,
#          'corporate': 899,
#          'massaging': 15,
#          'matsuyama': 1,
#          'bellow': 1,
#          '(original)': 1,
#          "annalise's": 1,
#          'absurdities': 2,
#          's-iii': 1,
#          'tennant?': 2,
#          'anxietydisorder': 1,
#          'militarily': 9,
#          '[faculty': 1,
#          'moleskin?': 1,
#          'commoncrawl': 1,
#          'upsides': 3,
#          'advancement': 18,
#          'm.tech/me': 1,
#          'keynesians': 1,
#          'pays,': 1,
#          'misdemeanor?': 5,
#          "mozart's": 1,
#          '(aetna)': 1,
#          "'arabic'?": 1,
#          '(business': 6,
#          'moleskine': 1,
#          '\xe8\x89\xb2\xe8\xbf\xb7\xe8\xbf\xb7\xe7\x9a\x84': 3,
#          'migaloo': 2,
#          'meatloaf?': 4,
#          'unequivocally': 4,
#          'objective': 143,
#          '(line': 1,
#          'indicative': 56,
#          'delorean?': 1,
#          'vetenary': 1,
#          'solid-state': 1,
#          '(3.06': 1,
#          'taxation)': 1,
#          '\xe2\x80\x9ckarma"?': 9,
#          '"complacent"': 1,
#          'keynesian,': 2,
#          'mode/aperture': 1,
#          'lacroix': 3,
#          'theory"?': 5,
#          '(3.0)': 1,
#          'upside-': 1,
#          "mts's": 1,
#          'misdemeanors': 4,
#          'latuda,': 1,
#          'excuses.': 1,
#          'longines?': 1,
#          '"family"?': 1,
#          'crowd': 33,
#          'crowe': 2,
#          'rankwise?': 1,
#          'jobs)': 4,
#          'crown': 59,
#          'q1010i?': 1,
#          'crows': 21,
#          '[math]x![/math]?': 1,
#          '25-40': 2,
#          'tear-drop': 1,
#          '(4.4.2)': 2,
#          'spaceship?': 3,
#          'conpany?': 1,
#          '(cpi)': 3,
#          'unlinke': 1,
#          'sentellas': 1,
#          'completly': 4,
#          'anyboudy': 1,
#          'crow"': 1,
#          'wtiter?': 1,
#          "doesn't?": 26,
#          'revealing/tight': 1,
#          'siteore.com?': 2,
#          'a332?': 3,
#          '577,000': 1,
#          'c4h10': 1,
#          "doesn't)": 1,
#          'google.?': 3,
#          'unfollow/"unfriend"': 1,
#          'masturation?': 12,
#          'free??': 1,
#          'caskets': 2,
#          'crow?': 5,
#          'restlessness': 2,
#          'spaceships': 7,
#          "dashlane's": 1,
#          'anomalous': 3,
#          '\xe0\xb2\xa4\xe0\xb2\xa4\xe0\xb3\x8d\xe0\xb2\xb8\xe0\xb2\xae': 1,
#          'ptsd': 20,
#          'vonage': 2,
#          '4-month': 3,
#          'trump/clinton': 1,
#          'routine/boring?': 1,
#          'p.i.)?': 1,
#          'exam.can': 1,
#          'university)': 12,
#          'pre-tax': 2,
#          'university.': 65,
#          'italicized?': 2,
#          'university,': 130,
#          'university"': 2,
#          'marshall': 35,
#          'honeymoon': 137,
#          'rotj,': 1,
#          'kissmetrics?': 1,
#          'university:': 23,
#          '(ncert': 1,
#          'university?': 1110,
#          'marshals': 5,
#          'saarc,': 1,
#          'despised': 4,
#          'screens)': 1,
#          'fabric': 94,
#          'aetna?': 2,
#          '\xc2\xa31000000': 3,
#          'kolkatta?': 3,
#          'revenues?': 15,
#          'saarc?': 7,
#          'screens?': 19,
#          'grasping': 5,
#          'yepme?': 2,
#          'screens:': 1,
#          'rapes': 30,
#          'revenues)': 2,
#          'dadhichi': 1,
#          'b/1': 1,
#          'humble?': 12,
#          '(officer': 1,
#          'venmo?': 5,
#          'thesaurus': 5,
#          'kid?"?': 1,
#          'china-pakistan': 4,
#          '(dji': 2,
#          'universitys': 1,
#          'venmo.': 1,
#          'venmo,': 5,
#          'anti-intellectual?': 3,
#          'akhtar/farhaan': 1,
#          'one-on-one?': 1,
#          'braces.': 7,
#          'rape)': 1,
#          'braces,': 1,
#          'humbled': 1,
#          'system.what': 1,
#          'rape,': 10,
#          'gottafeeling.com?': 2,
#          'graduations:': 3,
#          'graduations?': 3,
#          'alexandria?': 4,
#          'braces?': 42,
#          'open-air': 1,
#          'nicest': 92,
#          'soldering': 7,
#          'prepration': 6,
#          'someone"?': 2,
#          'cno?': 1,
#          'passenger': 102,
#          'palm?': 35,
#          'rechecking': 1,
#          'bedsheet': 1,
#          'slideshare': 3,
#          'guy.i': 1,
#          'pending."': 1,
#          '1080x2560': 1,
#          'flooding)?': 1,
#          'cambodia': 536,
#          'creepiest/scariest': 6,
#          'serous': 1,
#          'crowne': 1,
#          ':computer': 4,
#          'oklahoma': 40,
#          'serverless': 2,
#          'modern"': 1,
#          'delight"?': 1,
#          'palms': 20,
#          'modern)': 1,
#          'modern,': 3,
#          'spokane,': 2,
#          'collumn': 1,
#          'yellowstone': 18,
#          '"chuy"?': 1,
#          '"evaluation"?': 1,
#          'verb+object+verb?': 1,
#          "bahrain's?": 2,
#          'leviathan?': 1,
#          'modern?': 7,
#          "'prodigal'": 1,
#          'crown?': 7,
#          '(p.s.u.)?': 1,
#          'hypoallergenic': 1,
#          "naver's": 2,
#          '(jeopardy,': 1,
#          '"export"-"download"?': 1,
#          '(successful)': 1,
#          'omran': 1,
#          'crown,': 1,
#          'enjoyed"?': 1,
#          '304,ielts': 1,
#          'crown)': 1,
#          'guy.?': 1,
#          'cognex?': 1,
#          'crown"': 1,
#          'you\xe2\x80\x9d(in': 1,
#          'jer,': 1,
#          'quota)?': 1,
#          'chail': 2,
#          'portioresearch.com?': 1,
#          'chain': 266,
#          'whoever': 12,
#          'user(s)': 1,
#          'bluerock': 1,
#          'chaid': 1,
#          'hr/recruiting': 1,
#          'innerspring': 2,
#          'ingroup': 1,
#          'blunders?': 1,
#          'chair': 49,
#          'macht': 1,
#          'machu': 3,
#          'ballet': 29,
#          'amplification': 3,
#          'baller': 1,
#          'grappler': 1,
#          '(september/october/november': 1,
#          'empathy,use': 1,
#          'rabinder': 2,
#          'megawatts': 1,
#          'illustrator,': 5,
#          'fractions?': 20,
#          'prometheus,': 1,
#          'shakeh,': 2,
#          'connecting': 113,
#          'illustrator:': 2,
#          'prometheus?': 1,
#          'illustrator?': 28,
#          '2x4?': 1,
#          'jerk': 39,
#          'lard': 5,
#          'enflamed': 1,
#          'olympus': 6,
#          'extension?': 25,
#          'gloomy': 5,
#          'rechargable': 3,
#          'goodrem': 2,
#          'exact': 344,
#          'minute': 196,
#          '(navel)': 2,
#          'mach?': 3,
#          'illustrators': 1,
#          '"ai"?': 1,
#          'shoulders"?': 1,
#          'sinx/x': 1,
#          "stern's": 4,
#          '"bade': 1,
#          "martha's": 2,
#          '"bada': 1,
#          '[math]\\dfrac{a}{1+a}': 1,
#          'trisha': 3,
#          '[math](p': 1,
#          'ogled': 1,
#          'mouth:$,': 1,
#          'buuz': 1,
#          'mentors/doctors': 1,
#          '[math](x': 1,
#          'bagging': 2,
#          'rapping': 3,
#          'azerbaijanis?': 2,
#          'matram': 1,
#          '\xe2\x80\x9chot': 2,
#          '\xe2\x80\x9chow': 9,
#          'abdullah': 6,
#          'nh2nh2': 4,
#          'demonitasation': 1,
#          'sts-107': 6,
#          'beeps?': 1,
#          'developping': 2,
#          '"gundu"': 1,
#          'geography': 182,
#          'airbus?': 17,
#          'unintentionally': 18,
#          'corvettes,': 1,
#          'j-pop-ish?': 1,
#          'drafted': 13,
#          'subbaraj': 1,
#          'lesson\xe2\x80\x99': 1,
#          'oldies': 1,
#          '"bad"': 10,
#          'hypertension)?': 1,
#          '[math](1': 3,
#          'bioreference': 1,
#          'benson': 2,
#          '"find"?': 7,
#          'nineties?': 4,
#          'zr?': 1,
#          'irredeemably,': 1,
#          'conjectures?': 1,
#          'wavii': 3,
#          '"seen': 1,
#          'religion/faith?': 2,
#          "'yoga'?": 1,
#          '30^100': 3,
#          'channel131.com?': 2,
#          'bharat?': 13,
#          'sound/noise': 1,
#          'he/him': 1,
#          'chauss\xc3\xa9e': 1,
#          "bharat'": 1,
#          'servamp,': 1,
#          'religion/cult?': 1,
#          'debt-based': 1,
#          'slept,': 1,
#          'slept.': 1,
#          'anerobic': 1,
#          'tayyibah': 2,
#          'handbags': 4,
#          'chats.': 1,
#          '(x1+x2)': 1,
#          'pints': 6,
#          'cheap/good': 1,
#          'vigour': 1,
#          'slept?': 5,
#          'chats?': 22,
#          'wank': 1,
#          '19*9*9?': 1,
#          'source/website': 1,
#          "kleenex's": 1,
#          'varient': 1,
#          '56k/month.': 1,
#          'cats,': 4,
#          'wonderfully?': 1,
#          'approving': 6,
#          'bharata': 2,
#          'utd?': 2,
#          '72.66': 1,
#          'almost(99%)': 1,
#          'cats:': 3,
#          'cardinality': 3,
#          'k-drama': 1,
#          'cats?': 178,
#          'rebounding': 1,
#          "depot's": 2,
#          '1,2,3,4and5th': 1,
#          '"skins"?': 1,
#          '[math]2a^4': 1,
#          'handbag?': 9,
#          'rutherford': 12,
#          'following': 1043,
#          'handbag,': 1,
#          '1877=778=8969': 2,
#          'heard?': 636,
#          'axiscades': 1,
#          'calcarea': 1,
#          'institutes,': 1,
#          'greco-turkish': 1,
#          '(patrol': 1,
#          'heard)': 1,
#          'heard/': 1,
#          'heard,': 19,
#          'adwords/content': 1,
#          'meningitis?': 2,
#          'gate(ee)?': 1,
#          'litre': 24,
#          'upneda?': 1,
#          'non-portable?': 1,
#          'bros.?': 1,
#          'thanking': 5,
#          'youthfunda.com': 1,
#          'substandard,': 7,
#          'quarterbacks?': 4,
#          'tmux,': 1,
#          'one\xe2\x80\x9d?': 1,
#          '(ultimate': 2,
#          'affix/root': 2,
#          'externality?': 1,
#          '(stick': 1,
#          'fueled': 6,
#          'online-shop': 1,
#          'vulkan': 1,
#          'insitute': 2,
#          'harmon': 4,
#          'culture/traditions': 1,
#          'denbury': 5,
#          'surfing': 30,
#          '100\xc2\xb0c': 1,
#          'sandeep': 22,
#          'qurayza?': 1,
#          'nebbish': 1,
#          '(maths)?': 1,
#          'mallaya': 1,
#          'skirmish': 2,
#          'ocassionally': 1,
#          'impactful': 4,
#          'jasprit': 1,
#          'webpage': 24,
#          'jungwirth': 1,
#          'newspapers/magazines': 1,
#          'cervix?': 5,
#          'gossped': 1,
#          '2.5-year-old': 1,
#          ...})

# %%
def get_weight(count, eps=10000, min_count=2):
    if count < min_count:
        return 0
    else:
        return 1.0000 / (count + eps)

# %%
weights = {word: get_weight(count) for word, count in counts.items()}
weights
# Out:
# {'considered,': 0,
#  'considered.': 0,
#  'pieces/rest': 0,
#  '(nfl)': 0,
#  'daiict': 9.997000899730081e-05,
#  'sunflowers?': 9.996001599360256e-05,
#  'throwaround': 0,
#  'telepat.io?': 9.997000899730081e-05,
#  'considered?': 9.981036031540073e-05,
#  'woods': 9.982032341784787e-05,
#  'spiders': 9.921619208254787e-05,
#  'campari?': 0,
#  'paiza': 0,
#  'woody': 9.989012086704625e-05,
#  'sunflowers,': 0,
#  'do/while': 0,
#  'regularize': 0,
#  "'guess'": 0,
#  "'context": 0,
#  '"ipod"?': 0,
#  'hallucinate': 9.995002498750625e-05,
#  'shadowdancer': 0,
#  'rickman': 9.997000899730081e-05,
#  '"epitome': 0,
#  'statute': 9.984025559105431e-05,
#  "propeller's": 0,
#  'naturopathic': 0,
#  'nature)?': 9.997000899730081e-05,
#  'gnetophyta?': 0,
#  'wood,': 9.997000899730081e-05,
#  'trojan': 9.982032341784787e-05,
#  'wood.': 0,
#  'pigment': 9.997000899730081e-05,
#  'tourister': 9.99000999000999e-05,
#  'gazatted': 0,
#  'spider?': 9.977052778609199e-05,
#  'wood:': 0,
#  'screaming': 9.989012086704625e-05,
#  'wood?': 9.942334460131238e-05,
#  'kaushal': 0,
#  'grueling': 0,
#  'wooden': 9.971083856815236e-05,
#  'wednesday': 9.974067424695791e-05,
#  ':computer': 9.996001599360256e-05,
#  'chameleons': 9.998000399920016e-05,
#  'amplifications': 0,
#  'light\xe2\x80\xa6': 0,
#  '/projects': 0,
#  'affiliate?': 9.989012086704625e-05,
#  'are,like': 0,
#  'thrace': 0,
#  'mailing?': 0,
#  'crunchyroll,': 0,
#  'lumira': 0,
#  'egrecharge,': 0,
#  '27,': 9.977052778609199e-05,
#  'to"grow': 0,
#  '27.': 9.996001599360256e-05,
#  '270': 9.9930048965724e-05,
#  'affiliate,': 0,
#  'crunchyroll?': 9.996001599360256e-05,
#  '275': 9.998000399920016e-05,
#  '276': 9.998000399920016e-05,
#  '277': 0,
#  '278': 9.9930048965724e-05,
#  '279': 9.997000899730081e-05,
#  '(swarna': 0,
#  'targa': 0,
#  'poverty,corruption,lack': 0,
#  '27?': 9.955201592832254e-05,
#  'capital-output': 0,
#  'kernel"': 0,
#  'dialogs': 0,
#  'kid:': 9.998000399920016e-05,
#  'kid?': 9.890218573830482e-05,
#  'warmongering': 0,
#  'anti-muslims?': 0,
#  'usenet': 9.998000399920016e-05,
#  'numeral': 9.996001599360256e-05,
#  '3-series': 0,
#  'kid,': 9.991008092716555e-05,
#  'fetch/display': 0,
#  'kid.': 9.9930048965724e-05,
#  "'pleasure": 0,
#  'snuggle?': 0,
#  'trivikram': 9.996001599360256e-05,
#  'gasket?': 9.99000999000999e-05,
#  'bhubaneshwar': 9.996001599360256e-05,
#  'affiliates': 9.99000999000999e-05,
#  't250si': 0,
#  'madhav?': 0,
#  'affiliated': 9.958175662218681e-05,
#  'motorolla': 0,
#  '5.7engine': 0,
#  'kids': 9.51022349025202e-05,
#  'uplifting': 9.995002498750625e-05,
#  '"produced': 0,
#  'dialog?': 0,
#  'deferring': 0,
#  'jerry,': 0,
#  'controversy': 9.981036031540073e-05,
#  'neurologist': 9.988014382740711e-05,
#  'how?': 9.017132551848512e-05,
#  'imporatnace': 0,
#  '(football': 9.998000399920016e-05,
#  'topography': 9.996001599360256e-05,
#  'whiteys?': 0,
#  'population?': 9.881422924901186e-05,
#  'dittofish?': 9.998000399920016e-05,
#  'population:': 0,
#  'screen)?': 0,
#  'write/read': 0,
#  'population,': 9.989012086704625e-05,
#  'population.': 0,
#  'sneha': 9.998000399920016e-05,
#  'population)': 9.998000399920016e-05,
#  'dne': 0,
#  'dnd': 9.997000899730081e-05,
#  'scope-sap': 0,
#  'dnf': 0,
#  'dna': 9.72951936174353e-05,
#  'dnc': 9.953219866626854e-05,
#  'dnb': 9.996001599360256e-05,
#  'overdamped,': 0,
#  ',delhi': 9.998000399920016e-05,
#  '(between': 9.997000899730081e-05,
#  'dnt': 9.995002498750625e-05,
#  'pgdhrm': 0,
#  'refunding': 9.998000399920016e-05,
#  'dnp': 0,
#  'dns': 9.979044007584074e-05,
#  'dnr': 9.998000399920016e-05,
#  'processor\xe2\x80\x99': 9.996001599360256e-05,
#  'ability.': 9.996001599360256e-05,
#  'unlearnable': 0,
#  'fltreasurehunt.org': 0,
#  'twenty19': 0,
#  'populations': 9.986019572598362e-05,
#  'contessa?': 0,
#  'yahoo': 9.408222786715589e-05,
#  'husband.': 9.994003597841295e-05,
#  '(z+x)': 0,
#  'hover': 9.981036031540073e-05,
#  '(rsi):': 0,
#  'bluerock': 0,
#  'thefoundation.com?': 9.997000899730081e-05,
#  'ambari': 9.997000899730081e-05,
#  'passable?': 0,
#  'spokane?': 0,
#  'enflamed': 0,
#  'sidebar?': 9.991008092716555e-05,
#  'paperbooks?': 0,
#  'libertatians': 0,
#  'blackmailed?': 9.998000399920016e-05,
#  '"an,"': 0,
#  '(sarjapur': 0,
#  'lesson\xe2\x80\x99': 0,
#  'namami': 9.996001599360256e-05,
#  "'d'.": 0,
#  'pints': 9.994003597841295e-05,
#  '<100': 0,
#  'pc/laptop': 9.998000399920016e-05,
#  'torqouise': 0,
#  'oliveboard': 0,
#  'dinosaur,': 0,
#  'm605dh?': 9.996001599360256e-05,
#  'titanium': 9.970089730807577e-05,
#  'assimilate?': 0,
#  'tss.already': 0,
#  'dota/dota2?': 9.998000399920016e-05,
#  'ltspice.': 0,
#  'pinto': 9.991008092716555e-05,
#  'dinosaur?': 9.995002498750625e-05,
#  'chapters?': 9.992006394884092e-05,
#  'duniya': 0,
#  'tchaikovsky': 9.994003597841295e-05,
#  'wharton': 9.969095803010666e-05,
#  'endurance?': 9.98003992015968e-05,
#  "'resist": 0,
#  '"celeron",': 9.998000399920016e-05,
#  'equivalencies': 0,
#  "blg'": 0,
#  'subtitles.?': 0,
#  'prostitues': 0,
#  'i.c.': 0,
#  'climaxing': 9.998000399920016e-05,
#  'tuesday..place': 0,
#  '214(b)': 9.997000899730081e-05,
#  'shaitan': 0,
#  'assimilated': 0,
#  'pint?': 9.996001599360256e-05,
#  'quorarian?': 0,
#  '(kid': 9.998000399920016e-05,
#  'dinosaurs': 9.935419771485345e-05,
#  'wrong': 8.777319406653208e-05,
#  "by'?": 0,
#  "post''": 0,
#  '(aerospace)': 0,
#  'sentencing': 9.998000399920016e-05,
#  'glandular': 0,
#  'spider)': 0,
#  'caste/tribe': 9.998000399920016e-05,
#  'niice?': 0,
#  '18s': 9.998000399920016e-05,
#  'shreya': 9.991008092716555e-05,
#  'stress=load/area': 0,
#  'narcos?': 9.996001599360256e-05,
#  'kiloton': 0,
#  'cck-gaba': 0,
#  'prostitue?': 0,
#  'narcos,': 9.998000399920016e-05,
#  'tighter?': 9.997000899730081e-05,
#  'disengaging': 9.998000399920016e-05,
#  'n*(n-1)?': 0,
#  '(etl': 0,
#  'shiva?': 9.945300845350572e-05,
#  'haringey?': 9.997000899730081e-05,
#  'welcomed': 9.960159362549801e-05,
#  'stoicism': 9.995002498750625e-05,
#  'dx[/math]': 9.996001599360256e-05,
#  'shiva,': 9.996001599360256e-05,
#  'voucher,': 9.998000399920016e-05,
#  'meteorology?': 0,
#  'concurrency': 9.998000399920016e-05,
#  'boltons': 0,
#  'activating': 9.9930048965724e-05,
#  'welcomes': 9.998000399920016e-05,
#  'fir': 9.976057462090982e-05,
#  'fis': 9.998000399920016e-05,
#  'fit': 9.635767970707265e-05,
#  'fiu': 0,
#  'lifeline': 9.998000399920016e-05,
#  'bringing': 9.821253191907288e-05,
#  'fix': 8.880206020779682e-05,
#  'striking': 9.98302885095338e-05,
#  'non-vegan': 0,
#  'sp-sb23w.': 0,
#  'fig': 9.998000399920016e-05,
#  '350,thunderbird': 0,
#  'fuddruckers': 0,
#  'fii': 9.996001599360256e-05,
#  'fin': 9.9930048965724e-05,
#  'fil': 9.998000399920016e-05,
#  '10.6.8?': 9.994003597841295e-05,
#  'welcome.': 9.995002498750625e-05,
#  'nothing.\xe2\x80\x9d': 0,
#  "welcome'": 0,
#  'vouchers': 9.994003597841295e-05,
#  'welcome"': 9.996001599360256e-05,
#  'shivam': 9.997000899730081e-05,
#  'welcome?': 9.995002498750625e-05,
#  'bolton?': 9.997000899730081e-05,
#  '[apart': 0,
#  'html-3d': 0,
#  '(increse/decrease)': 0,
#  'returnwealth.com?': 0,
#  'barton': 0,
#  'fi?': 9.994003597841295e-05,
#  'fi"': 9.998000399920016e-05,
#  '(x-r)': 0,
#  'bartow': 9.997000899730081e-05,
#  'editing,animation,': 0,
#  'spayed?': 9.995002498750625e-05,
#  'achem': 0,
#  'shakes/eating': 0,
#  'concurrency)?': 0,
#  'nzt?': 0,
#  'pumpkin,': 0,
#  'company).': 0,
#  'company),': 9.998000399920016e-05,
#  'childen': 9.998000399920016e-05,
#  'cramming?': 9.998000399920016e-05,
#  'propoganda': 0,
#  'embarrased?': 0,
#  '2day': 9.998000399920016e-05,
#  'company):': 9.996001599360256e-05,
#  'company)?': 9.99000999000999e-05,
#  'pumpkin?': 9.995002498750625e-05,
#  'installing)?': 0,
#  'combinatorial': 0,
#  "'lalbaugcha": 0,
#  's2e3?': 0,
#  'shivaji?': 9.997000899730081e-05,
#  'guitarists': 9.9930048965724e-05,
#  'abbott': 9.996001599360256e-05,
#  'affair)?': 0,
#  'anti-brahminism?': 0,
#  'start-up.': 0,
#  'hades,': 9.998000399920016e-05,
#  "'binoculars'": 9.998000399920016e-05,
#  'for/towards': 9.987016878058524e-05,
#  'partitiate': 0,
#  'pumpkins': 9.994003597841295e-05,
#  '6qn': 0,
#  '"supply"': 0,
#  'histology?': 9.995002498750625e-05,
#  'nasty?': 9.998000399920016e-05,
#  'antilia,': 0,
#  '$800,000': 9.998000399920016e-05,
#  'categorical': 9.986019572598362e-05,
#  'technologies/languages': 0,
#  'bookmark': 9.979044007584074e-05,
#  'nasty,': 0,
#  'dgw': 0,
#  '27"': 0,
#  'anal/oral': 9.998000399920016e-05,
#  '[math]\\sum_': 0,
#  'quagmire?': 9.998000399920016e-05,
#  'megabytes': 9.995002498750625e-05,
#  '27%': 0,
#  '[math]\\tan{\\theta}': 0,
#  'olds': 9.970089730807577e-05,
#  'renovated': 9.998000399920016e-05,
#  'manipal?': 9.96512207274539e-05,
#  'pug/cavalier': 9.976057462090982e-05,
#  'd5500': 9.99000999000999e-05,
#  'needed': 9.3976130062964e-05,
#  'master': 9.485866059571239e-05,
#  'manipal.': 9.998000399920016e-05,
#  'manipal/': 0,
#  'manipal!': 0,
#  "indata's": 0,
#  'genesis': 9.978048293753742e-05,
#  'death/black': 0,
#  '1-i?': 0,
#  '"ich"': 9.998000399920016e-05,
#  'accords?': 9.997000899730081e-05,
#  'organization?"': 0,
#  'lazer?': 9.998000399920016e-05,
#  'clementi,': 0,
#  'motionless': 9.998000399920016e-05,
#  'quirky,': 0,
#  'receptionist?': 9.997000899730081e-05,
#  "fischer's": 9.998000399920016e-05,
#  'desiccant': 9.997000899730081e-05,
#  'modernity?': 0,
#  'positively': 9.960159362549801e-05,
#  'condesending': 0,
#  'ahmed': 9.9930048965724e-05,
#  'fruit?': 9.937394415184339e-05,
#  'ooopps': 0,
#  'addicted?': 9.9930048965724e-05,
#  'duckworth': 9.996001599360256e-05,
#  'photo-essays': 0,
#  'old?': 9.476876421531463e-05,
#  'doppelgangers?': 0,
#  'old"': 0,
#  'addicted,': 9.998000399920016e-05,
#  'addicted.': 0,
#  'old)': 9.976057462090982e-05,
#  '274': 0,
#  'old-': 0,
#  'old,': 9.831874938550782e-05,
#  'old.': 9.797198001371608e-05,
#  'i.a.s..': 9.998000399920016e-05,
#  'yeezys': 9.998000399920016e-05,
#  '(1974': 9.997000899730081e-05,
#  '(1972': 0,
#  '(1973': 0,
#  '(1971': 9.998000399920016e-05,
#  'shipment?': 9.997000899730081e-05,
#  'craven': 9.998000399920016e-05,
#  'consenting': 9.996001599360256e-05,
#  'andromeda?': 9.994003597841295e-05,
#  'kuamari': 9.997000899730081e-05,
#  'mishra': 9.9930048965724e-05,
#  'devar/bhabhi?': 0,
#  'dedupe': 0,
#  '7.5%.': 0,
#  'actor/actress?': 9.98003992015968e-05,
#  'abusing?': 0,
#  'credentialed': 0,
#  '(soccer).': 0,
#  '(soccer),': 9.998000399920016e-05,
#  'fugitive.': 0,
#  'rhce': 9.9930048965724e-05,
#  'willing?': 9.998000399920016e-05,
#  '(soccer):': 9.997000899730081e-05,
#  '(soccer)?': 9.995002498750625e-05,
#  '(sms)': 9.998000399920016e-05,
#  'batna,': 0,
#  'fugitive?': 0,
#  'expectorant?': 9.998000399920016e-05,
#  'inanimate': 9.992006394884092e-05,
#  'kremlin': 9.995002498750625e-05,
#  'shipments': 9.996001599360256e-05,
#  '45th': 9.976057462090982e-05,
#  "'00s": 0,
#  "ssd's": 9.997000899730081e-05,
#  'icloud': 9.74089226573154e-05,
#  'kenobi?': 9.998000399920016e-05,
#  'under-ride': 0,
#  'spinning"': 0,
#  'funny/clever': 9.998000399920016e-05,
#  'scariest/weirdest': 0,
#  'gyazo?': 0,
#  'spinning,': 9.997000899730081e-05,
#  'practicing,': 9.998000399920016e-05,
#  'practicing.': 0,
#  'tech': 8.99199712256092e-05,
#  'ache,': 0,
#  'expectorants': 9.998000399920016e-05,
#  'teck': 0,
#  'spinning?': 9.977052778609199e-05,
#  "'e'": 9.996001599360256e-05,
#  'doesn\xe2\x80\x99t': 9.882399446585631e-05,
#  '(brihanmumbai': 0,
#  'practicing?': 9.996001599360256e-05,
#  '20/15': 9.998000399920016e-05,
#  'clubs/pubs': 0,
#  'barakhamba': 0,
#  'islamabad,': 9.996001599360256e-05,
#  'braising': 9.995002498750625e-05,
#  'damaged.': 9.996001599360256e-05,
#  'damaged,': 9.9930048965724e-05,
#  'nsit/dtu?': 0,
#  '(mcgraw': 0,
#  'programs(applied': 0,
#  'hunter)?': 0,
#  'spreecommerce': 0,
#  'islamabad?': 9.995002498750625e-05,
#  'damaged?': 9.976057462090982e-05,
#  'neistat?': 9.997000899730081e-05,
#  'tempted': 9.9930048965724e-05,
#  'uifn?': 0,
#  'fz16?': 0,
#  'mandy"': 9.998000399920016e-05,
#  'excavator': 0,
#  '$10,000/yr': 0,
#  'kinase': 9.998000399920016e-05,
#  'lube': 9.991008092716555e-05,
#  'non-iodized': 9.997000899730081e-05,
#  'xlvii': 0,
#  'self-destructive?': 0,
#  'nangloi,': 0,
#  'electronics/comm': 0,
#  'hills?': 9.987016878058524e-05,
#  'iata': 9.994003597841295e-05,
#  'migraines?': 9.991008092716555e-05,
#  'nerds?': 9.9930048965724e-05,
#  'amla?': 0,
#  'photoelectric': 9.992006394884092e-05,
#  'kid)': 9.998000399920016e-05,
#  '40\xc2\xb0c-30\xc2\xb0c': 0,
#  'r\xc3\xa9mi': 9.997000899730081e-05,
#  'optimise': 9.995002498750625e-05,
#  'loan-based': 9.998000399920016e-05,
#  "bankers'": 0,
#  '{cout<<"main': 0,
#  'patch': 9.957184108334163e-05,
#  'train/bus': 0,
#  '(cms)': 0,
#  'apac?': 9.991008092716555e-05,
#  '(january': 9.995002498750625e-05,
#  'programmatic': 9.996001599360256e-05,
#  'idea?)': 0,
#  'purse.io': 0,
#  'heirloom': 9.998000399920016e-05,
#  'subtills': 0,
#  'warts/hpv': 0,
#  "test's": 0,
#  'spectrometer?': 9.992006394884092e-05,
#  'dobara': 0,
#  'counries': 9.998000399920016e-05,
#  'ijert?': 0,
#  '1070?': 9.994003597841295e-05,
#  'tyndall': 9.994003597841295e-05,
#  'epithelium': 0,
#  'irr': 9.989012086704625e-05,
#  'irs': 9.915716410510659e-05,
#  'extenders.': 0,
#  'irl': 9.995002498750625e-05,
#  'irm': 9.997000899730081e-05,
#  'irn': 9.998000399920016e-05,
#  'conductive': 9.998000399920016e-05,
#  'subarray': 0,
#  'irb': 0,
#  'irc': 9.982032341784787e-05,
#  'ire': 0,
#  'nptel?': 9.994003597841295e-05,
#  'discipline': 9.937394415184339e-05,
#  '$3-4k': 0,
#  '27k': 9.998000399920016e-05,
#  'seriously?': 9.892175289346128e-05,
#  'extend': 9.915716410510659e-05,
#  'nature': 9.788566953797964e-05,
#  'mcdonalds?': 9.994003597841295e-05,
#  'conan?': 9.991008092716555e-05,
#  'optimist': 9.997000899730081e-05,
#  'story-writer?': 0,
#  'accreditated': 0,
#  'nike+fuelband': 0,
#  'eti?': 0,
#  'seriously.': 9.998000399920016e-05,
#  'extent': 9.801038910124473e-05,
#  'seriously,': 9.989012086704625e-05,
#  'tendons': 9.998000399920016e-05,
#  'camapign,': 0,
#  'described,': 9.805844283192783e-05,
#  'ir?': 9.998000399920016e-05,
#  'sparta': 9.997000899730081e-05,
#  'directly?': 9.958175662218681e-05,
#  'described?': 9.928514694201747e-05,
#  'quora/facebook': 0,
#  'underestimated?': 9.989012086704625e-05,
#  'glutamine': 9.997000899730081e-05,
#  'ir%': 0,
#  'tidewater?': 0,
#  'directly,': 9.992006394884092e-05,
#  'audi/bmw/mercedes': 0,
#  "doubt'": 0,
#  'doubt"': 0,
#  'propellant)': 0,
#  'doubt,': 9.996001599360256e-05,
#  'doubt.': 9.997000899730081e-05,
#  'solidworks?': 9.991008092716555e-05,
#  'hairline': 9.9930048965724e-05,
#  "'sent": 0,
#  'word/phrase?': 9.995002498750625e-05,
#  'anti-pakistan': 0,
#  'month-long': 9.998000399920016e-05,
#  'humming': 9.996001599360256e-05,
#  'doubt?': 9.996001599360256e-05,
#  'gasket.': 0,
#  'smackdown': 9.997000899730081e-05,
#  'apples?': 9.972078181092939e-05,
#  '3.80': 0,
#  '3.8?': 9.998000399920016e-05,
#  'apples.': 0,
#  'apples,': 9.996001599360256e-05,
#  'crossed-leg': 9.996001599360256e-05,
#  '3.8%': 0,
#  'non-married': 0,
#  '"one': 9.952229299363058e-05,
#  'obese': 9.975062344139652e-05,
#  'doramas?': 9.998000399920016e-05,
#  '2lpa?': 0,
#  'hepa': 9.997000899730081e-05,
#  'doubts': 9.976057462090982e-05,
#  'tv/movie?': 0,
#  'hepl': 0,
#  '$2,000?': 9.9930048965724e-05,
#  'chips\xe2\x80\x99': 0,
#  'carmax?': 9.997000899730081e-05,
#  'zakath': 0,
#  'amazonsmile': 0,
#  'tax-efficient': 0,
#  'professionally': 9.971083856815236e-05,
#  'paraglider': 0,
#  'screenwriters?': 9.998000399920016e-05,
#  'somatrophin': 0,
#  '"on"': 9.988014382740711e-05,
#  'ejb?': 9.998000399920016e-05,
#  '505,': 0,
#  'scum': 0,
#  'majie': 0,
#  'step-down': 0,
#  'zeo)': 0,
#  'majin': 0,
#  'plants?': 9.872642906506072e-05,
#  'desperately?': 0,
#  'plants:': 9.997000899730081e-05,
#  'purposes': 9.948269001193792e-05,
#  '505?': 0,
#  '5059': 0,
#  'waddell': 0,
#  'plants,': 9.978048293753742e-05,
#  'plants.': 0,
#  'desperately.': 9.998000399920016e-05,
#  'multi-orgasmic?': 9.997000899730081e-05,
#  'desperately,': 9.998000399920016e-05,
#  'mentor?': 9.906875371507826e-05,
#  'memorial': 9.99000999000999e-05,
#  'denied"?': 0,
#  'translations?': 9.991008092716555e-05,
#  '[math]x^2-2px+2p^4[/math],': 0,
#  'mentor.': 0,
#  'anupam)': 9.998000399920016e-05,
#  'crytocurrency': 0,
#  '(google),': 9.998000399920016e-05,
#  'embargo?': 9.998000399920016e-05,
#  'squashing': 0,
#  '$480,000?': 0,
#  '5"10.': 0,
#  '5"10,': 0,
#  '"has"': 9.997000899730081e-05,
#  'syllabusdesk.com?': 0,
#  'boxer"?': 0,
#  'rommmates?': 0,
#  'const.)?': 0,
#  'error,': 9.995002498750625e-05,
#  'mentors': 9.984025559105431e-05,
#  '0\xc3\x97infinity?': 0,
#  'nalco?': 0,
#  'demonetization,while': 0,
#  'lonelier': 9.998000399920016e-05,
#  '"soft-max"': 9.998000399920016e-05,
#  'corporate': 9.175153683824204e-05,
#  'massaging': 9.985022466300549e-05,
#  'bellow': 0,
#  '(original)': 0,
#  "annalise's": 0,
#  'absurdities': 9.998000399920016e-05,
#  's-iii': 0,
#  'tennant?': 9.998000399920016e-05,
#  'anxietydisorder': 0,
#  'militarily': 9.991008092716555e-05,
#  '[faculty': 0,
#  'moleskin?': 0,
#  'commoncrawl': 0,
#  'upsides': 9.997000899730081e-05,
#  'advancement': 9.982032341784787e-05,
#  'm.tech/me': 0,
#  'keynesians': 0,
#  'pays,': 0,
#  'misdemeanor?': 9.995002498750625e-05,
#  "mozart's": 0,
#  '(aetna)': 0,
#  "'arabic'?": 0,
#  '(business': 9.994003597841295e-05,
#  'moleskine': 0,
#  '\xe8\x89\xb2\xe8\xbf\xb7\xe8\xbf\xb7\xe7\x9a\x84': 9.997000899730081e-05,
#  'meatloaf?': 9.996001599360256e-05,
#  'unequivocally': 9.996001599360256e-05,
#  'objective': 9.859016070196194e-05,
#  '(line': 0,
#  'indicative': 9.94431185361973e-05,
#  'delorean?': 0,
#  'vetenary': 0,
#  'solid-state': 0,
#  '(3.06': 0,
#  'taxation)': 0,
#  '\xe2\x80\x9ckarma"?': 9.991008092716555e-05,
#  '"complacent"': 0,
#  'keynesian,': 9.998000399920016e-05,
#  'mode/aperture': 0,
#  '\xc2\xbfomg?': 0,
#  'theory"?': 9.995002498750625e-05,
#  '(3.0)': 0,
#  'upside-': 0,
#  "mts's": 0,
#  'misdemeanors': 9.996001599360256e-05,
#  'latuda,': 0,
#  'longines?': 0,
#  '"family"?': 0,
#  'crowd': 9.96710854181202e-05,
#  'crowe': 9.998000399920016e-05,
#  'rankwise?': 0,
#  'jobs)': 9.996001599360256e-05,
#  'crown': 9.941346058256288e-05,
#  'q1010i?': 0,
#  'crows': 9.979044007584074e-05,
#  '[math]x![/math]?': 0,
#  '25-40': 9.998000399920016e-05,
#  'tear-drop': 0,
#  '(4.4.2)': 9.998000399920016e-05,
#  'spaceship?': 9.997000899730081e-05,
#  'fourcores)?': 0,
#  'conpany?': 0,
#  '(cpi)': 9.997000899730081e-05,
#  'unlinke': 0,
#  'sentellas': 0,
#  'completly': 9.996001599360256e-05,
#  'anyboudy': 0,
#  'crow"': 0,
#  'wtiter?': 0,
#  "doesn't?": 9.974067424695791e-05,
#  'revealing/tight': 0,
#  'siteore.com?': 9.998000399920016e-05,
#  'a332?': 9.997000899730081e-05,
#  '577,000': 0,
#  'c4h10': 0,
#  "doesn't)": 0,
#  'google.?': 9.997000899730081e-05,
#  'unfollow/"unfriend"': 0,
#  'masturation?': 9.988014382740711e-05,
#  'free??': 0,
#  'caskets': 9.998000399920016e-05,
#  'crow?': 9.995002498750625e-05,
#  'restlessness': 9.998000399920016e-05,
#  'spaceships': 9.9930048965724e-05,
#  "dashlane's": 0,
#  'sane"?': 0,
#  '\xe0\xb2\xa4\xe0\xb2\xa4\xe0\xb3\x8d\xe0\xb2\xb8\xe0\xb2\xae': 0,
#  'ptsd': 9.98003992015968e-05,
#  'vonage': 9.998000399920016e-05,
#  '4-month': 9.997000899730081e-05,
#  'trump/clinton': 0,
#  'routine/boring?': 0,
#  'p.i.)?': 0,
#  'exam.can': 0,
#  'university)': 9.988014382740711e-05,
#  'had516': 0,
#  'pre-tax': 9.998000399920016e-05,
#  'university.': 9.935419771485345e-05,
#  'italicized?': 9.998000399920016e-05,
#  'university,': 9.871668311944718e-05,
#  'university"': 9.998000399920016e-05,
#  'marshall': 9.96512207274539e-05,
#  'honeymoon': 9.864851533984413e-05,
#  'rotj,': 0,
#  'kauravs?': 0,
#  'kissmetrics?': 0,
#  'university:': 9.977052778609199e-05,
#  '(ncert': 0,
#  '7.7/10': 0,
#  'marshals': 9.995002498750625e-05,
#  'saarc,': 0,
#  'despised': 9.996001599360256e-05,
#  'screens)': 0,
#  'fabric': 9.906875371507826e-05,
#  'aetna?': 9.998000399920016e-05,
#  '\xc2\xa31000000': 9.997000899730081e-05,
#  'kolkatta?': 9.997000899730081e-05,
#  'revenues?': 9.985022466300549e-05,
#  'saarc?': 9.9930048965724e-05,
#  'screens?': 9.981036031540073e-05,
#  'grasping': 9.995002498750625e-05,
#  'screens:': 0,
#  'rapes': 9.970089730807577e-05,
#  'revenues)': 9.998000399920016e-05,
#  'dadhichi': 0,
#  'humble?': 9.988014382740711e-05,
#  '(officer': 0,
#  'venmo?': 9.995002498750625e-05,
#  'thesaurus': 9.995002498750625e-05,
#  'kid?"?': 0,
#  'china-pakistan': 9.996001599360256e-05,
#  '(dji': 9.998000399920016e-05,
#  'universitys': 0,
#  'venmo.': 0,
#  'venmo,': 9.995002498750625e-05,
#  'anti-intellectual?': 9.997000899730081e-05,
#  'akhtar/farhaan': 0,
#  'one-on-one?': 0,
#  'braces.': 9.9930048965724e-05,
#  'rape)': 0,
#  'braces,': 0,
#  'humbled': 0,
#  'system.what': 0,
#  'rape,': 9.99000999000999e-05,
#  'gottafeeling.com?': 9.998000399920016e-05,
#  'graduations:': 9.997000899730081e-05,
#  'graduations?': 9.997000899730081e-05,
#  'alexandria?': 9.996001599360256e-05,
#  'braces?': 9.958175662218681e-05,
#  'open-air': 0,
#  'rape?': 9.94431185361973e-05,
#  'soldering': 9.9930048965724e-05,
#  'prepration': 9.994003597841295e-05,
#  'someone"?': 9.998000399920016e-05,
#  'cno?': 0,
#  'helicopter,': 9.99000999000999e-05,
#  'passenger': 9.899029895070283e-05,
#  'palm?': 9.96512207274539e-05,
#  'rechecking': 0,
#  'bedsheet': 0,
#  'slideshare': 9.997000899730081e-05,
#  'guy.i': 0,
#  'pending."': 0,
#  '1080x2560': 0,
#  'flooding)?': 0,
#  'cambodia': 9.491268033409264e-05,
#  'creepiest/scariest': 9.994003597841295e-05,
#  'serous': 0,
#  'crowne': 0,
#  'serverless': 9.998000399920016e-05,
#  'modern"': 0,
#  'delight"?': 0,
#  'palms': 9.98003992015968e-05,
#  'modern)': 0,
#  'modern,': 9.997000899730081e-05,
#  'todefence?': 0,
#  'spokane,': 9.998000399920016e-05,
#  'yellowstone': 9.982032341784787e-05,
#  '"evaluation"?': 0,
#  'verb+object+verb?': 0,
#  "bahrain's?": 9.998000399920016e-05,
#  'leviathan?': 0,
#  "good-looking'?": 9.998000399920016e-05,
#  "'prodigal'": 0,
#  'crown?': 9.9930048965724e-05,
#  '(p.s.u.)?': 0,
#  'hypoallergenic': 0,
#  "naver's": 9.998000399920016e-05,
#  '(jeopardy,': 0,
#  '"export"-"download"?': 0,
#  '(successful)': 0,
#  'omran': 0,
#  'crown,': 0,
#  'enjoyed"?': 0,
#  '304,ielts': 0,
#  'crown)': 0,
#  'guy.?': 0,
#  'cognex?': 0,
#  'crown"': 0,
#  'you\xe2\x80\x9d(in': 0,
#  'jer,': 0,
#  'quota)?': 0,
#  'chail': 9.998000399920016e-05,
#  'portioresearch.com?': 0,
#  'chain': 9.74089226573154e-05,
#  'whoever': 9.988014382740711e-05,
#  'user(s)': 0,
#  'romanovs?': 0,
#  'chaid': 0,
#  'hr/recruiting': 0,
#  'innerspring': 9.998000399920016e-05,
#  "estes'": 0,
#  'blunders?': 0,
#  'chair': 9.95123892924669e-05,
#  'macht': 0,
#  'machu': 9.997000899730081e-05,
#  'ballet': 9.971083856815236e-05,
#  'amplification': 9.997000899730081e-05,
#  'baller': 0,
#  'grappler': 0,
#  '(september/october/november': 0,
#  'empathy,use': 0,
#  'rabinder': 9.998000399920016e-05,
#  'megawatts': 0,
#  'illustrator,': 9.995002498750625e-05,
#  'fractions?': 9.98003992015968e-05,
#  'prometheus,': 0,
#  'shakeh,': 9.998000399920016e-05,
#  'larg': 9.998000399920016e-05,
#  'illustrator:': 9.998000399920016e-05,
#  'prometheus?': 0,
#  'illustrator?': 9.972078181092939e-05,
#  '150gms': 0,
#  '2x4?': 0,
#  'jerk': 9.961151509114453e-05,
#  '1,2,3,4,': 0,
#  'equilateral': 9.975062344139652e-05,
#  'olympus': 9.994003597841295e-05,
#  '"laser"': 0,
#  'gloomy': 9.995002498750625e-05,
#  'rechargable': 9.997000899730081e-05,
#  'goodrem': 9.998000399920016e-05,
#  'exact': 9.667440061871617e-05,
#  'minute': 9.807767752059631e-05,
#  '(navel)': 9.998000399920016e-05,
#  'onam?': 0,
#  'mach?': 9.997000899730081e-05,
#  'illustrators': 0,
#  '"ai"?': 0,
#  'shoulders"?': 0,
#  'ovotestis': 0,
#  'sinx/x': 0,
#  "stern's": 9.996001599360256e-05,
#  '"bade': 0,
#  "martha's": 9.998000399920016e-05,
#  '"bada': 0,
#  '[math]\\dfrac{a}{1+a}': 0,
#  'trisha': 9.997000899730081e-05,
#  '[math](p': 0,
#  'ogled': 0,
#  'mouth:$,': 0,
#  'buuz': 0,
#  'mentors/doctors': 0,
#  '[math](x': 0,
#  'bagging': 9.998000399920016e-05,
#  'rapping': 9.997000899730081e-05,
#  'azerbaijanis?': 9.998000399920016e-05,
#  'matram': 0,
#  '\xe2\x80\x9chot': 9.998000399920016e-05,
#  '\xe2\x80\x9chow': 9.991008092716555e-05,
#  'abdullah': 9.994003597841295e-05,
#  'nh2nh2': 9.996001599360256e-05,
#  'demonitasation': 0,
#  'sts-107': 9.994003597841295e-05,
#  'beeps?': 0,
#  '"gundu"': 0,
#  'ground': 9.732360097323601e-05,
#  'airbus?': 9.98302885095338e-05,
#  'unintentionally': 9.982032341784787e-05,
#  'corvettes,': 0,
#  'j-pop-ish?': 0,
#  'drafted': 9.987016878058524e-05,
#  'subbaraj': 0,
#  'v^2/r?': 0,
#  'howking?': 0,
#  'symmetrical?': 9.995002498750625e-05,
#  '"bad"': 9.99000999000999e-05,
#  'hypertension)?': 0,
#  '[math](1': 9.997000899730081e-05,
#  'benson': 9.998000399920016e-05,
#  '"find"?': 9.9930048965724e-05,
#  '(paroxetine),': 9.998000399920016e-05,
#  'zr?': 0,
#  'irredeemably,': 0,
#  'conjectures?': 0,
#  'wavii': 9.997000899730081e-05,
#  '"seen': 0,
#  'religion/faith?': 9.998000399920016e-05,
#  "'yoga'?": 0,
#  '30^100': 9.997000899730081e-05,
#  'channel131.com?': 9.998000399920016e-05,
#  'bharat?': 9.987016878058524e-05,
#  'sound/noise': 0,
#  'he/him': 0,
#  'chauss\xc3\xa9e': 0,
#  "bharat'": 0,
#  'texture': 9.982032341784787e-05,
#  'religion/cult?': 0,
#  'debt-based': 0,
#  'slept,': 0,
#  'slept.': 0,
#  'anerobic': 0,
#  'tayyibah': 9.998000399920016e-05,
#  'handbags': 9.996001599360256e-05,
#  'chats.': 0,
#  '(x1+x2)': 0,
#  'hyatt': 9.998000399920016e-05,
#  'cheap/good': 0,
#  'vigour': 0,
#  'slept?': 9.995002498750625e-05,
#  'chats?': 9.978048293753742e-05,
#  'wank': 0,
#  '19*9*9?': 0,
#  'source/website': 0,
#  "kleenex's": 0,
#  'varient': 0,
#  '56k/month.': 0,
#  'cats,': 9.996001599360256e-05,
#  'wonderfully?': 0,
#  'approving': 9.994003597841295e-05,
#  'bharata': 9.998000399920016e-05,
#  'utd?': 9.998000399920016e-05,
#  '72.66': 0,
#  'almost(99%)': 0,
#  'cats:': 9.997000899730081e-05,
#  'cardinality': 9.997000899730081e-05,
#  'k-drama': 0,
#  'cats?': 9.825112988799372e-05,
#  'rebounding': 0,
#  "depot's": 9.998000399920016e-05,
#  '1,2,3,4and5th': 0,
#  '"skins"?': 0,
#  '[math]2a^4': 0,
#  'handbag?': 9.991008092716555e-05,
#  'rutherford': 9.988014382740711e-05,
#  'following': 9.055510278004166e-05,
#  'handbag,': 0,
#  '1877=778=8969': 9.998000399920016e-05,
#  'heard?': 9.40203083866115e-05,
#  'axiscades': 0,
#  'calcarea': 0,
#  'institutes,': 0,
#  'greco-turkish': 0,
#  '(patrol': 0,
#  'heard)': 0,
#  'heard/': 0,
#  'heard,': 9.981036031540073e-05,
#  'adwords/content': 0,
#  'meningitis?': 9.998000399920016e-05,
#  'gate(ee)?': 0,
#  'litre': 9.976057462090982e-05,
#  'upneda?': 0,
#  'non-portable?': 0,
#  'bros.?': 0,
#  'thanking': 9.995002498750625e-05,
#  'youthfunda.com': 0,
#  'substandard,': 9.9930048965724e-05,
#  'quarterbacks?': 9.996001599360256e-05,
#  'tmux,': 0,
#  'one\xe2\x80\x9d?': 0,
#  '(ultimate': 9.998000399920016e-05,
#  'args[])?': 0,
#  'externality?': 0,
#  '(stick': 0,
#  'fueled': 9.994003597841295e-05,
#  'online-shop': 0,
#  'vulkan': 0,
#  'insitute': 9.998000399920016e-05,
#  'harmon': 9.996001599360256e-05,
#  '"bowling': 9.998000399920016e-05,
#  'culture/traditions': 0,
#  'denbury': 9.995002498750625e-05,
#  'surfing': 9.970089730807577e-05,
#  '100\xc2\xb0c': 0,
#  'sandeep': 9.978048293753742e-05,
#  'nebbish': 0,
#  '(maths)?': 0,
#  'mallaya': 0,
#  'skirmish': 9.998000399920016e-05,
#  'ocassionally': 0,
#  'impactful': 9.996001599360256e-05,
#  'jasprit': 0,
#  '\xe2\x80\x98just': 0,
#  'webpage': 9.976057462090982e-05,
#  'jungwirth': 0,
#  'newspapers/magazines': 0,
#  'cervix?': 9.995002498750625e-05,
#  'gossped': 0,
#  '2.5-year-old': 0,
#  'look\xe2\x80\x9d': 0,
#  '\xe2\x80\x9chey\xe2\x80\x9d': 9.998000399920016e-05,
#  'peverells?': 0,
#  'multipath': 0,
#  ...}

# %%
print('Most common words and weights: \n')
print(sorted(weights.items(), key=lambda x: x[1] if x[1] > 0 else 9999)[:10])
print('\nLeast common words and weights: ')
(sorted(weights.items(), key=lambda x: x[1], reverse=True)[:10])
# Out:
# Most common words and weights:
#
# [('the', 2.5891040146646852e-06), ('what', 3.115623919267953e-06), ('is', 3.5861702928825277e-06), ('how', 4.366449945201053e-06), ('i', 4.4805878531263305e-06), ('a', 4.540645588989843e-06), ('to', 4.671434644293609e-06), ('in', 4.884625153865692e-06), ('of', 5.920242493132519e-06), ('do', 6.070908207867897e-06)]
#
# Least common words and weights:
# [('chameleons', 9.998000399920016e-05),
#  ('275', 9.998000399920016e-05),
#  ('276', 9.998000399920016e-05),
#  ('kid:', 9.998000399920016e-05),
#  ('usenet', 9.998000399920016e-05),
#  ('(football', 9.998000399920016e-05),
#  ('dittofish?', 9.998000399920016e-05),
#  ('sneha', 9.998000399920016e-05),
#  ('population)', 9.998000399920016e-05),
#  (',delhi', 9.998000399920016e-05)]

# %%
len(weights)
# Out:
# 201105

# %%
def tfidf_word_match_share(row):
    q1words = {}
    q2words = {}
    for word in str(row['question1']).lower().split():
        if word not in stops:
            q1words[word] = 1
    for word in str(row['question2']).lower().split():
        if word not in stops:
            q2words[word] = 1
    if len(q1words) == 0 or len(q2words) == 0:
        return 0
    
    shared_weights = [weights.get(w, 0) for w in q1words.keys() if w in q2words] \
                   + [weights.get(w, 0) for w in q2words.keys() if w in q1words]
    total_weights = [weights.get(w, 0) for w in q1words] + \
                    [weights.get(w, 0) for w in q2words]
    

    try:
        R = 1.00000* np.sum(shared_weights) / np.sum(total_weights)
    except ZeroDivisionError:
        R = 0
    return R

# %%
tfidf_train_word_match = df_train.apply(tfidf_word_match_share, axis=1, raw=True)
tfidf_train_word_match
# Out:
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:16: RuntimeWarning: invalid value encountered in double_scalars
# 0         0.772164
# 1         0.361758
# 2         0.355191
# 3         0.000000
# 4         0.000000
# 5         0.510771
# 6         0.000000
# 7         0.645836
# 8         0.396755
# 9         0.503203
# 10        0.000000
# 11        0.654071
# 12        1.000000
# 13        0.536457
# 14        0.804625
# 15        0.307390
# 16        0.536711
# 17        0.000000
# 18        0.532416
# 19        0.488021
# 20        0.589277
# 21        0.000000
# 22        0.652711
# 23        0.000000
# 24        0.000000
# 25        0.720855
# 26        0.353365
# 27        0.000000
# 28        0.762706
# 29        0.527833
#             ...
# 404260    0.382804
# 404261    0.578849
# 404262    0.668261
# 404263    0.330545
# 404264    0.249702
# 404265    0.346612
# 404266    0.166106
# 404267    0.826632
# 404268    0.000000
# 404269    0.755497
# 404270    0.228984
# 404271    0.000000
# 404272    0.382578
# 404273    0.583512
# 404274    0.368606
# 404275    0.000000
# 404276    0.000000
# 404277    0.000000
# 404278    0.259237
# 404279    0.369876
# 404280    0.904533
# 404281    0.668606
# 404282    0.459886
# 404283    0.253353
# 404284    0.845724
# 404285    0.828152
# 404286    0.657463
# 404287    0.712011
# 404288    0.000000
# 404289    1.000000
# dtype: float64

# %%
# plt.figure(figsize=(15, 5))
# plt.hist(tfidf_train_word_match[df_train['is_duplicate'] == 0].fillna(0), bins=20, normed=True, label='Not Duplicate')
# plt.hist(tfidf_train_word_match[df_train['is_duplicate'] == 1].fillna(0), bins=20, normed=True, alpha=0.7, label='Duplicate')
# plt.legend()
# plt.title('Label distribution over tfidf_word_match_share', fontsize=15)
# plt.xlabel('word_match_share', fontsize=15)

# %%
from sklearn.metrics import roc_auc_score
print('Original AUC:', roc_auc_score(df_train['is_duplicate'], train_word_match))
print('   TFIDF AUC:', roc_auc_score(df_train['is_duplicate'], tfidf_train_word_match.fillna(0)))
# Out:
# ('Original AUC:', 0.78055320062812139)
# ('   TFIDF AUC:', 0.77056665661851498)

# %% [markdown]
# # Using sklearn TF-IDF and do some pre-cleaning.

# %%
import re

def questions_to_words( raw_review ):
    ''' Convert questions to words using regular expresssion, \
    removing stopwrods, and keep only alphabets'''

    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", raw_review) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
train_qs.shape[0]
# Out:
# 808580

# %%
print("Cleaning and parsing the training set movie reviews...\n")
clean_train_reviews = []
for i in range( 0, train_qs.shape[0]):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print("Review %d of %d\n" % ( i+1, train_qs.shape[0] ))
    clean_train_reviews.append( questions_to_words( train_qs[i] ))
# Out:
# Cleaning and parsing the training set movie reviews...
#
# Review 1000 of 808580
#
# Review 2000 of 808580
#
# Review 3000 of 808580
#
# Review 4000 of 808580
#
# Review 5000 of 808580
#
# Review 6000 of 808580
#
# Review 7000 of 808580
#
# Review 8000 of 808580
#
# Review 9000 of 808580
#
# Review 10000 of 808580
#
# Review 11000 of 808580
#
# Review 12000 of 808580
#
# Review 13000 of 808580
#
# Review 14000 of 808580
#
# Review 15000 of 808580
#
# Review 16000 of 808580
#
# Review 17000 of 808580
#
# Review 18000 of 808580
#
# Review 19000 of 808580
#
# Review 20000 of 808580
#
# Review 21000 of 808580
#
# Review 22000 of 808580
#
# Review 23000 of 808580
#
# Review 24000 of 808580
#
# Review 25000 of 808580
#
# Review 26000 of 808580
#
# Review 27000 of 808580
#
# Review 28000 of 808580
#
# Review 29000 of 808580
#
# Review 30000 of 808580
#
# Review 31000 of 808580
#
# Review 32000 of 808580
#
# Review 33000 of 808580
#
# Review 34000 of 808580
#
# Review 35000 of 808580
#
# Review 36000 of 808580
#
# Review 37000 of 808580
#
# Review 38000 of 808580
#
# Review 39000 of 808580
#
# Review 40000 of 808580
#
# Review 41000 of 808580
#
# Review 42000 of 808580
#
# Review 43000 of 808580
#
# Review 44000 of 808580
#
# Review 45000 of 808580
#
# Review 46000 of 808580
#
# Review 47000 of 808580
#
# Review 48000 of 808580
#
# Review 49000 of 808580
#
# Review 50000 of 808580
#
# Review 51000 of 808580
#
# Review 52000 of 808580
#
# Review 53000 of 808580
#
# Review 54000 of 808580
#
# Review 55000 of 808580
#
# Review 56000 of 808580
#
# Review 57000 of 808580
#
# Review 58000 of 808580
#
# Review 59000 of 808580
#
# Review 60000 of 808580
#
# Review 61000 of 808580
#
# Review 62000 of 808580
#
# Review 63000 of 808580
#
# Review 64000 of 808580
#
# Review 65000 of 808580
#
# Review 66000 of 808580
#
# Review 67000 of 808580
#
# Review 68000 of 808580
#
# Review 69000 of 808580
#
# Review 70000 of 808580
#
# Review 71000 of 808580
#
# Review 72000 of 808580
#
# Review 73000 of 808580
#
# Review 74000 of 808580
#
# Review 75000 of 808580
#
# Review 76000 of 808580
#
# Review 77000 of 808580
#
# Review 78000 of 808580
#
# Review 79000 of 808580
#
# Review 80000 of 808580
#
# Review 81000 of 808580
#
# Review 82000 of 808580
#
# Review 83000 of 808580
#
# Review 84000 of 808580
#
# Review 85000 of 808580
#
# Review 86000 of 808580
#
# Review 87000 of 808580
#
# Review 88000 of 808580
#
# Review 89000 of 808580
#
# Review 90000 of 808580
#
# Review 91000 of 808580
#
# Review 92000 of 808580
#
# Review 93000 of 808580
#
# Review 94000 of 808580
#
# Review 95000 of 808580
#
# Review 96000 of 808580
#
# Review 97000 of 808580
#
# Review 98000 of 808580
#
# Review 99000 of 808580
#
# Review 100000 of 808580
#
# Review 101000 of 808580
#
# Review 102000 of 808580
#
# Review 103000 of 808580
#
# Review 104000 of 808580
#
# Review 105000 of 808580
#
# Review 106000 of 808580
#
# Review 107000 of 808580
#
# Review 108000 of 808580
#
# Review 109000 of 808580
#
# Review 110000 of 808580
#
# Review 111000 of 808580
#
# Review 112000 of 808580
#
# Review 113000 of 808580
#
# Review 114000 of 808580
#
# Review 115000 of 808580
#
# Review 116000 of 808580
#
# Review 117000 of 808580
#
# Review 118000 of 808580
#
# Review 119000 of 808580
#
# Review 120000 of 808580
#
# Review 121000 of 808580
#
# Review 122000 of 808580
#
# Review 123000 of 808580
#
# Review 124000 of 808580
#
# Review 125000 of 808580
#
# Review 126000 of 808580
#
# Review 127000 of 808580
#
# Review 128000 of 808580
#
# Review 129000 of 808580
#
# Review 130000 of 808580
#
# Review 131000 of 808580
#
# Review 132000 of 808580
#
# Review 133000 of 808580
#
# Review 134000 of 808580
#
# Review 135000 of 808580
#
# Review 136000 of 808580
#
# Review 137000 of 808580
#
# Review 138000 of 808580
#
# Review 139000 of 808580
#
# Review 140000 of 808580
#
# Review 141000 of 808580
#
# Review 142000 of 808580
#
# Review 143000 of 808580
#
# Review 144000 of 808580
#
# Review 145000 of 808580
#
# Review 146000 of 808580
#
# Review 147000 of 808580
#
# Review 148000 of 808580
#
# Review 149000 of 808580
#
# Review 150000 of 808580
#
# Review 151000 of 808580
#
# Review 152000 of 808580
#
# Review 153000 of 808580
#
# Review 154000 of 808580
#
# Review 155000 of 808580
#
# Review 156000 of 808580
#
# Review 157000 of 808580
#
# Review 158000 of 808580
#
# Review 159000 of 808580
#
# Review 160000 of 808580
#
# Review 161000 of 808580
#
# Review 162000 of 808580
#
# Review 163000 of 808580
#
# Review 164000 of 808580
#
# Review 165000 of 808580
#
# Review 166000 of 808580
#
# Review 167000 of 808580
#
# Review 168000 of 808580
#
# Review 169000 of 808580
#
# Review 170000 of 808580
#
# Review 171000 of 808580
#
# Review 172000 of 808580
#
# Review 173000 of 808580
#
# Review 174000 of 808580
#
# Review 175000 of 808580
#
# Review 176000 of 808580
#
# Review 177000 of 808580
#
# Review 178000 of 808580
#
# Review 179000 of 808580
#
# Review 180000 of 808580
#
# Review 181000 of 808580
#
# Review 182000 of 808580
#
# Review 183000 of 808580
#
# Review 184000 of 808580
#
# Review 185000 of 808580
#
# Review 186000 of 808580
#
# Review 187000 of 808580
#
# Review 188000 of 808580
#
# Review 189000 of 808580
#
# Review 190000 of 808580
#
# Review 191000 of 808580
#
# Review 192000 of 808580
#
# Review 193000 of 808580
#
# Review 194000 of 808580
#
# Review 195000 of 808580
#
# Review 196000 of 808580
#
# Review 197000 of 808580
#
# Review 198000 of 808580
#
# Review 199000 of 808580
#
# Review 200000 of 808580
#
# Review 201000 of 808580
#
# Review 202000 of 808580
#
# Review 203000 of 808580
#
# Review 204000 of 808580
#
# Review 205000 of 808580
#
# Review 206000 of 808580
#
# Review 207000 of 808580
#
# Review 208000 of 808580
#
# Review 209000 of 808580
#
# Review 210000 of 808580
#
# Review 211000 of 808580
#
# Review 212000 of 808580
#
# Review 213000 of 808580
#
# Review 214000 of 808580
#
# Review 215000 of 808580
#
# Review 216000 of 808580
#
# Review 217000 of 808580
#
# Review 218000 of 808580
#
# Review 219000 of 808580
#
# Review 220000 of 808580
#
# Review 221000 of 808580
#
# Review 222000 of 808580
#
# Review 223000 of 808580
#
# Review 224000 of 808580
#
# Review 225000 of 808580
#
# Review 226000 of 808580
#
# Review 227000 of 808580
#
# Review 228000 of 808580
#
# Review 229000 of 808580
#
# Review 230000 of 808580
#
# Review 231000 of 808580
#
# Review 232000 of 808580
#
# Review 233000 of 808580
#
# Review 234000 of 808580
#
# Review 235000 of 808580
#
# Review 236000 of 808580
#
# Review 237000 of 808580
#
# Review 238000 of 808580
#
# Review 239000 of 808580
#
# Review 240000 of 808580
#
# Review 241000 of 808580
#
# Review 242000 of 808580
#
# Review 243000 of 808580
#
# Review 244000 of 808580
#
# Review 245000 of 808580
#
# Review 246000 of 808580
#
# Review 247000 of 808580
#
# Review 248000 of 808580
#
# Review 249000 of 808580
#
# Review 250000 of 808580
#
# Review 251000 of 808580
#
# Review 252000 of 808580
#
# Review 253000 of 808580
#
# Review 254000 of 808580
#
# Review 255000 of 808580
#
# Review 256000 of 808580
#
# Review 257000 of 808580
#
# Review 258000 of 808580
#
# Review 259000 of 808580
#
# Review 260000 of 808580
#
# Review 261000 of 808580
#
# Review 262000 of 808580
#
# Review 263000 of 808580
#
# Review 264000 of 808580
#
# Review 265000 of 808580
#
# Review 266000 of 808580
#
# Review 267000 of 808580
#
# Review 268000 of 808580
#
# Review 269000 of 808580
#
# Review 270000 of 808580
#
# Review 271000 of 808580
#
# Review 272000 of 808580
#
# Review 273000 of 808580
#
# Review 274000 of 808580
#
# Review 275000 of 808580
#
# Review 276000 of 808580
#
# Review 277000 of 808580
#
# Review 278000 of 808580
#
# Review 279000 of 808580
#
# Review 280000 of 808580
#
# Review 281000 of 808580
#
# Review 282000 of 808580
#
# Review 283000 of 808580
#
# Review 284000 of 808580
#
# Review 285000 of 808580
#
# Review 286000 of 808580
#
# Review 287000 of 808580
#
# Review 288000 of 808580
#
# Review 289000 of 808580
#
# Review 290000 of 808580
#
# Review 291000 of 808580
#
# Review 292000 of 808580
#
# Review 293000 of 808580
#
# Review 294000 of 808580
#
# Review 295000 of 808580
#
# Review 296000 of 808580
#
# Review 297000 of 808580
#
# Review 298000 of 808580
#
# Review 299000 of 808580
#
# Review 300000 of 808580
#
# Review 301000 of 808580
#
# Review 302000 of 808580
#
# Review 303000 of 808580
#
# Review 304000 of 808580
#
# Review 305000 of 808580
#
# Review 306000 of 808580
#
# Review 307000 of 808580
#
# Review 308000 of 808580
#
# Review 309000 of 808580
#
# Review 310000 of 808580
#
# Review 311000 of 808580
#
# Review 312000 of 808580
#
# Review 313000 of 808580
#
# Review 314000 of 808580
#
# Review 315000 of 808580
#
# Review 316000 of 808580
#
# Review 317000 of 808580
#
# Review 318000 of 808580
#
# Review 319000 of 808580
#
# Review 320000 of 808580
#
# Review 321000 of 808580
#
# Review 322000 of 808580
#
# Review 323000 of 808580
#
# Review 324000 of 808580
#
# Review 325000 of 808580
#
# Review 326000 of 808580
#
# Review 327000 of 808580
#
# Review 328000 of 808580
#
# Review 329000 of 808580
#
# Review 330000 of 808580
#
# Review 331000 of 808580
#
# Review 332000 of 808580
#
# Review 333000 of 808580
#
# Review 334000 of 808580
#
# Review 335000 of 808580
#
# Review 336000 of 808580
#
# Review 337000 of 808580
#
# Review 338000 of 808580
#
# Review 339000 of 808580
#
# Review 340000 of 808580
#
# Review 341000 of 808580
#
# Review 342000 of 808580
#
# Review 343000 of 808580
#
# Review 344000 of 808580
#
# Review 345000 of 808580
#
# Review 346000 of 808580
#
# Review 347000 of 808580
#
# Review 348000 of 808580
#
# Review 349000 of 808580
#
# Review 350000 of 808580
#
# Review 351000 of 808580
#
# Review 352000 of 808580
#
# Review 353000 of 808580
#
# Review 354000 of 808580
#
# Review 355000 of 808580
#
# Review 356000 of 808580
#
# Review 357000 of 808580
#
# Review 358000 of 808580
#
# Review 359000 of 808580
#
# Review 360000 of 808580
#
# Review 361000 of 808580
#
# Review 362000 of 808580
#
# Review 363000 of 808580
#
# Review 364000 of 808580
#
# Review 365000 of 808580
#
# Review 366000 of 808580
#
# Review 367000 of 808580
#
# Review 368000 of 808580
#
# Review 369000 of 808580
#
# Review 370000 of 808580
#
# Review 371000 of 808580
#
# Review 372000 of 808580
#
# Review 373000 of 808580
#
# Review 374000 of 808580
#
# Review 375000 of 808580
#
# Review 376000 of 808580
#
# Review 377000 of 808580
#
# Review 378000 of 808580
#
# Review 379000 of 808580
#
# Review 380000 of 808580
#
# Review 381000 of 808580
#
# Review 382000 of 808580
#
# Review 383000 of 808580
#
# Review 384000 of 808580
#
# Review 385000 of 808580
#
# Review 386000 of 808580
#
# Review 387000 of 808580
#
# Review 388000 of 808580
#
# Review 389000 of 808580
#
# Review 390000 of 808580
#
# Review 391000 of 808580
#
# Review 392000 of 808580
#
# Review 393000 of 808580
#
# Review 394000 of 808580
#
# Review 395000 of 808580
#
# Review 396000 of 808580
#
# Review 397000 of 808580
#
# Review 398000 of 808580
#
# Review 399000 of 808580
#
# Review 400000 of 808580
#
# Review 401000 of 808580
#
# Review 402000 of 808580
#
# Review 403000 of 808580
#
# Review 404000 of 808580
#
# Review 405000 of 808580
#
# Review 406000 of 808580
#
# Review 407000 of 808580
#
# Review 408000 of 808580
#
# Review 409000 of 808580
#
# Review 410000 of 808580
#
# Review 411000 of 808580
#
# Review 412000 of 808580
#
# Review 413000 of 808580
#
# Review 414000 of 808580
#
# Review 415000 of 808580
#
# Review 416000 of 808580
#
# Review 417000 of 808580
#
# Review 418000 of 808580
#
# Review 419000 of 808580
#
# Review 420000 of 808580
#
# Review 421000 of 808580
#
# Review 422000 of 808580
#
# Review 423000 of 808580
#
# Review 424000 of 808580
#
# Review 425000 of 808580
#
# Review 426000 of 808580
#
# Review 427000 of 808580
#
# Review 428000 of 808580
#
# Review 429000 of 808580
#
# Review 430000 of 808580
#
# Review 431000 of 808580
#
# Review 432000 of 808580
#
# Review 433000 of 808580
#
# Review 434000 of 808580
#
# Review 435000 of 808580
#
# Review 436000 of 808580
#
# Review 437000 of 808580
#
# Review 438000 of 808580
#
# Review 439000 of 808580
#
# Review 440000 of 808580
#
# Review 441000 of 808580
#
# Review 442000 of 808580
#
# Review 443000 of 808580
#
# Review 444000 of 808580
#
# Review 445000 of 808580
#
# Review 446000 of 808580
#
# Review 447000 of 808580
#
# Review 448000 of 808580
#
# Review 449000 of 808580
#
# Review 450000 of 808580
#
# Review 451000 of 808580
#
# Review 452000 of 808580
#
# Review 453000 of 808580
#
# Review 454000 of 808580
#
# Review 455000 of 808580
#
# Review 456000 of 808580
#
# Review 457000 of 808580
#
# Review 458000 of 808580
#
# Review 459000 of 808580
#
# Review 460000 of 808580
#
# Review 461000 of 808580
#
# Review 462000 of 808580
#
# Review 463000 of 808580
#
# Review 464000 of 808580
#
# Review 465000 of 808580
#
# Review 466000 of 808580
#
# Review 467000 of 808580
#
# Review 468000 of 808580
#
# Review 469000 of 808580
#
# Review 470000 of 808580
#
# Review 471000 of 808580
#
# Review 472000 of 808580
#
# Review 473000 of 808580
#
# Review 474000 of 808580
#
# Review 475000 of 808580
#
# Review 476000 of 808580
#
# Review 477000 of 808580
#
# Review 478000 of 808580
#
# Review 479000 of 808580
#
# Review 480000 of 808580
#
# Review 481000 of 808580
#
# Review 482000 of 808580
#
# Review 483000 of 808580
#
# Review 484000 of 808580
#
# Review 485000 of 808580
#
# Review 486000 of 808580
#
# Review 487000 of 808580
#
# Review 488000 of 808580
#
# Review 489000 of 808580
#
# Review 490000 of 808580
#
# Review 491000 of 808580
#
# Review 492000 of 808580
#
# Review 493000 of 808580
#
# Review 494000 of 808580
#
# Review 495000 of 808580
#
# Review 496000 of 808580
#
# Review 497000 of 808580
#
# Review 498000 of 808580
#
# Review 499000 of 808580
#
# Review 500000 of 808580
#
# Review 501000 of 808580
#
# Review 502000 of 808580
#
# Review 503000 of 808580
#
# Review 504000 of 808580
#
# Review 505000 of 808580
#
# Review 506000 of 808580
#
# Review 507000 of 808580
#
# Review 508000 of 808580
#
# Review 509000 of 808580
#
# Review 510000 of 808580
#
# Review 511000 of 808580
#
# Review 512000 of 808580
#
# Review 513000 of 808580
#
# Review 514000 of 808580
#
# Review 515000 of 808580
#
# Review 516000 of 808580
#
# Review 517000 of 808580
#
# Review 518000 of 808580
#
# Review 519000 of 808580
#
# Review 520000 of 808580
#
# Review 521000 of 808580
#
# Review 522000 of 808580
#
# Review 523000 of 808580
#
# Review 524000 of 808580
#
# Review 525000 of 808580
#
# Review 526000 of 808580
#
# Review 527000 of 808580
#
# Review 528000 of 808580
#
# Review 529000 of 808580
#
# Review 530000 of 808580
#
# Review 531000 of 808580
#
# Review 532000 of 808580
#
# Review 533000 of 808580
#
# Review 534000 of 808580
#
# Review 535000 of 808580
#
# Review 536000 of 808580
#
# Review 537000 of 808580
#
# Review 538000 of 808580
#
# Review 539000 of 808580
#
# Review 540000 of 808580
#
# Review 541000 of 808580
#
# Review 542000 of 808580
#
# Review 543000 of 808580
#
# Review 544000 of 808580
#
# Review 545000 of 808580
#
# Review 546000 of 808580
#
# Review 547000 of 808580
#
# Review 548000 of 808580
#
# Review 549000 of 808580
#
# Review 550000 of 808580
#
# Review 551000 of 808580
#
# Review 552000 of 808580
#
# Review 553000 of 808580
#
# Review 554000 of 808580
#
# Review 555000 of 808580
#
# Review 556000 of 808580
#
# Review 557000 of 808580
#
# Review 558000 of 808580
#
# Review 559000 of 808580
#
# Review 560000 of 808580
#
# Review 561000 of 808580
#
# Review 562000 of 808580
#
# Review 563000 of 808580
#
# Review 564000 of 808580
#
# Review 565000 of 808580
#
# Review 566000 of 808580
#
# Review 567000 of 808580
#
# Review 568000 of 808580
#
# Review 569000 of 808580
#
# Review 570000 of 808580
#
# Review 571000 of 808580
#
# Review 572000 of 808580
#
# Review 573000 of 808580
#
# Review 574000 of 808580
#
# Review 575000 of 808580
#
# Review 576000 of 808580
#
# Review 577000 of 808580
#
# Review 578000 of 808580
#
# Review 579000 of 808580
#
# Review 580000 of 808580
#
# Review 581000 of 808580
#
# Review 582000 of 808580
#
# Review 583000 of 808580
#
# Review 584000 of 808580
#
# Review 585000 of 808580
#
# Review 586000 of 808580
#
# Review 587000 of 808580
#
# Review 588000 of 808580
#
# Review 589000 of 808580
#
# Review 590000 of 808580
#
# Review 591000 of 808580
#
# Review 592000 of 808580
#
# Review 593000 of 808580
#
# Review 594000 of 808580
#
# Review 595000 of 808580
#
# Review 596000 of 808580
#
# Review 597000 of 808580
#
# Review 598000 of 808580
#
# Review 599000 of 808580
#
# Review 600000 of 808580
#
# Review 601000 of 808580
#
# Review 602000 of 808580
#
# Review 603000 of 808580
#
# Review 604000 of 808580
#
# Review 605000 of 808580
#
# Review 606000 of 808580
#
# Review 607000 of 808580
#
# Review 608000 of 808580
#
# Review 609000 of 808580
#
# Review 610000 of 808580
#
# Review 611000 of 808580
#
# Review 612000 of 808580
#
# Review 613000 of 808580
#
# Review 614000 of 808580
#
# Review 615000 of 808580
#
# Review 616000 of 808580
#
# Review 617000 of 808580
#
# Review 618000 of 808580
#
# Review 619000 of 808580
#
# Review 620000 of 808580
#
# Review 621000 of 808580
#
# Review 622000 of 808580
#
# Review 623000 of 808580
#
# Review 624000 of 808580
#
# Review 625000 of 808580
#
# Review 626000 of 808580
#
# Review 627000 of 808580
#
# Review 628000 of 808580
#
# Review 629000 of 808580
#
# Review 630000 of 808580
#
# Review 631000 of 808580
#
# Review 632000 of 808580
#
# Review 633000 of 808580
#
# Review 634000 of 808580
#
# Review 635000 of 808580
#
# Review 636000 of 808580
#
# Review 637000 of 808580
#
# Review 638000 of 808580
#
# Review 639000 of 808580
#
# Review 640000 of 808580
#
# Review 641000 of 808580
#
# Review 642000 of 808580
#
# Review 643000 of 808580
#
# Review 644000 of 808580
#
# Review 645000 of 808580
#
# Review 646000 of 808580
#
# Review 647000 of 808580
#
# Review 648000 of 808580
#
# Review 649000 of 808580
#
# Review 650000 of 808580
#
# Review 651000 of 808580
#
# Review 652000 of 808580
#
# Review 653000 of 808580
#
# Review 654000 of 808580
#
# Review 655000 of 808580
#
# Review 656000 of 808580
#
# Review 657000 of 808580
#
# Review 658000 of 808580
#
# Review 659000 of 808580
#
# Review 660000 of 808580
#
# Review 661000 of 808580
#
# Review 662000 of 808580
#
# Review 663000 of 808580
#
# Review 664000 of 808580
#
# Review 665000 of 808580
#
# Review 666000 of 808580
#
# Review 667000 of 808580
#
# Review 668000 of 808580
#
# Review 669000 of 808580
#
# Review 670000 of 808580
#
# Review 671000 of 808580
#
# Review 672000 of 808580
#
# Review 673000 of 808580
#
# Review 674000 of 808580
#
# Review 675000 of 808580
#
# Review 676000 of 808580
#
# Review 677000 of 808580
#
# Review 678000 of 808580
#
# Review 679000 of 808580
#
# Review 680000 of 808580
#
# Review 681000 of 808580
#
# Review 682000 of 808580
#
# Review 683000 of 808580
#
# Review 684000 of 808580
#
# Review 685000 of 808580
#
# Review 686000 of 808580
#
# Review 687000 of 808580
#
# Review 688000 of 808580
#
# Review 689000 of 808580
#
# Review 690000 of 808580
#
# Review 691000 of 808580
#
# Review 692000 of 808580
#
# Review 693000 of 808580
#
# Review 694000 of 808580
#
# Review 695000 of 808580
#
# Review 696000 of 808580
#
# Review 697000 of 808580
#
# Review 698000 of 808580
#
# Review 699000 of 808580
#
# Review 700000 of 808580
#
# Review 701000 of 808580
#
# Review 702000 of 808580
#
# Review 703000 of 808580
#
# Review 704000 of 808580
#
# Review 705000 of 808580
#
# Review 706000 of 808580
#
# Review 707000 of 808580
#
# Review 708000 of 808580
#
# Review 709000 of 808580
#
# Review 710000 of 808580
#
# Review 711000 of 808580
#
# Review 712000 of 808580
#
# Review 713000 of 808580
#
# Review 714000 of 808580
#
# Review 715000 of 808580
#
# Review 716000 of 808580
#
# Review 717000 of 808580
#
# Review 718000 of 808580
#
# Review 719000 of 808580
#
# Review 720000 of 808580
#
# Review 721000 of 808580
#
# Review 722000 of 808580
#
# Review 723000 of 808580
#
# Review 724000 of 808580
#
# Review 725000 of 808580
#
# Review 726000 of 808580
#
# Review 727000 of 808580
#
# Review 728000 of 808580
#
# Review 729000 of 808580
#
# Review 730000 of 808580
#
# Review 731000 of 808580
#
# Review 732000 of 808580
#
# Review 733000 of 808580
#
# Review 734000 of 808580
#
# Review 735000 of 808580
#
# Review 736000 of 808580
#
# Review 737000 of 808580
#
# Review 738000 of 808580
#
# Review 739000 of 808580
#
# Review 740000 of 808580
#
# Review 741000 of 808580
#
# Review 742000 of 808580
#
# Review 743000 of 808580
#
# Review 744000 of 808580
#
# Review 745000 of 808580
#
# Review 746000 of 808580
#
# Review 747000 of 808580
#
# Review 748000 of 808580
#
# Review 749000 of 808580
#
# Review 750000 of 808580
#
# Review 751000 of 808580
#
# Review 752000 of 808580
#
# Review 753000 of 808580
#
# Review 754000 of 808580
#
# Review 755000 of 808580
#
# Review 756000 of 808580
#
# Review 757000 of 808580
#
# Review 758000 of 808580
#
# Review 759000 of 808580
#
# Review 760000 of 808580
#
# Review 761000 of 808580
#
# Review 762000 of 808580
#
# Review 763000 of 808580
#
# Review 764000 of 808580
#
# Review 765000 of 808580
#
# Review 766000 of 808580
#
# Review 767000 of 808580
#
# Review 768000 of 808580
#
# Review 769000 of 808580
#
# Review 770000 of 808580
#
# Review 771000 of 808580
#
# Review 772000 of 808580
#
# Review 773000 of 808580
#
# Review 774000 of 808580
#
# Review 775000 of 808580
#
# Review 776000 of 808580
#
# Review 777000 of 808580
#
# Review 778000 of 808580
#
# Review 779000 of 808580
#
# Review 780000 of 808580
#
# Review 781000 of 808580
#
# Review 782000 of 808580
#
# Review 783000 of 808580
#
# Review 784000 of 808580
#
# Review 785000 of 808580
#
# Review 786000 of 808580
#
# Review 787000 of 808580
#
# Review 788000 of 808580
#
# Review 789000 of 808580
#
# Review 790000 of 808580
#
# Review 791000 of 808580
#
# Review 792000 of 808580
#
# Review 793000 of 808580
#
# Review 794000 of 808580
#
# Review 795000 of 808580
#
# Review 796000 of 808580
#
# Review 797000 of 808580
#
# Review 798000 of 808580
#
# Review 799000 of 808580
#
# Review 800000 of 808580
#
# Review 801000 of 808580
#
# Review 802000 of 808580
#
# Review 803000 of 808580
#
# Review 804000 of 808580
#
# Review 805000 of 808580
#
# Review 806000 of 808580
#
# Review 807000 of 808580
#
# Review 808000 of 808580

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

print("Creating the bag of words...\n")

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = TfidfVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_df = 0.9, \
                             min_df = 2, \
                             max_features = 200000) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_train_reviews)

# Numpy arrays are easy to work with, so convert the result to an 
# array
# train_data_features = train_data_features.toarray()
train_data_features
# Out:
# Creating the bag of words...
# <808580x48595 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4191515 stored elements in Compressed Sparse Row format>

# %%
sk_weights = vectorizer.vocabulary_
sk_weights
# Out:
# {u'daiict': 10444,
#  u'gag': 16901,
#  u'woods': 47805,
#  u'spiders': 40647,
#  u'hanging': 18698,
#  u'woody': 47810,
#  u'localized': 25102,
#  u'disobeying': 12164,
#  u'refunding': 35822,
#  u'rickman': 36760,
#  u'pigment': 32483,
#  u'tourister': 44084,
#  u'replaces': 36235,
#  u'bringing': 5599,
#  u'kaushal': 23180,
#  u'vibrational': 46378,
#  u'wooden': 47800,
#  u'wednesday': 47251,
#  u'chameleons': 7115,
#  u'crotch': 10007,
#  u'thrace': 43517,
#  u'mormonthink': 28034,
#  u'desiccant': 11414,
#  u'selassie': 38469,
#  u'consenting': 9021,
#  u'inanimate': 20880,
#  u'errors': 14340,
#  u'starboy': 41046,
#  u'warmongering': 47016,
#  u'usenet': 45828,
#  u'designing': 11425,
#  u'numeral': 29839,
#  u'quaro': 34727,
#  u'trivikram': 44540,
#  u'bhubaneshwar': 4450,
#  u'brainwashed': 5418,
#  u'affiliates': 799,
#  u'evolutionist': 14646,
#  u'quart': 34732,
#  u'kids': 23440,
#  u'uplifting': 45700,
#  u'controversy': 9264,
#  u'neurologist': 29161,
#  u'topography': 43970,
#  u'projection': 34005,
#  u'stern': 41234,
#  u'sneha': 40038,
#  u'dnd': 12432,
#  u'dna': 12428,
#  u'dnc': 12430,
#  u'dnb': 12429,
#  u'insecurity': 21432,
#  u'dnt': 12435,
#  u'pgdhrm': 32199,
#  u'dns': 12434,
#  u'dnr': 12433,
#  u'skewness': 39675,
#  u'populations': 33142,
#  u'yahoo': 48158,
#  u'milestones': 27277,
#  u'adventist': 686,
#  u'equilateral': 14258,
#  u'morally': 28007,
#  u'wang': 46972,
#  u'wand': 46964,
#  u'hyatt': 20150,
#  u'wani': 46973,
#  u'oliveboard': 30243,
#  u'titanium': 43776,
#  u'want': 46977,
#  u'rayon': 35313,
#  u'pinto': 32560,
#  u'ferranti': 15553,
#  u'tchaikovsky': 42882,
#  u'travel': 44357,
#  u'ambala': 1465,
#  u'actionscript': 428,
#  u'dinosaurs': 11923,
#  u'wrong': 47975,
#  u'stipulate': 41301,
#  u'sentencing': 38588,
#  u'shreya': 39241,
#  u'recombination': 35569,
#  u'subplots': 41696,
#  u'kiloton': 23471,
#  u'menlo': 26853,
#  u'disengaging': 12111,
#  u'welcomed': 47306,
#  u'stoicism': 41328,
#  u'concurrency': 8818,
#  u'boltons': 5083,
#  u'activating': 433,
#  u'welcomes': 47307,
#  u'fir': 15817,
#  u'fis': 15852,
#  u'uop': 45657,
#  u'fit': 15875,
#  u'fiu': 15892,
#  u'lifeline': 24756,
#  u'screaming': 38205,
#  u'fix': 15898,
#  u'fig': 15669,
#  u'engenearing': 14002,
#  u'fii': 15684,
#  u'fin': 15742,
#  u'fil': 15689,
#  u'songwriter': 40309,
#  u'vouchers': 46784,
#  u'shivam': 39101,
#  u'photocell': 32341,
#  u'jamali': 22360,
#  u'hypoxia': 20291,
#  u'effects': 13427,
#  u'pandodaily': 31224,
#  u'mcgonagall': 26554,
#  u'bartow': 3813,
#  u'timeout': 43701,
#  u'parasites': 31357,
#  u'abhimanyu': 97,
#  u'rabbitmq': 34887,
#  u'getch': 17381,
#  u'enviroment': 14167,
#  u'combinatorial': 8434,
#  u'picaroworld': 32423,
#  u'adapt': 484,
#  u'size': 39634,
#  u'abbott': 63,
#  u'pumpkins': 34437,
#  u'stereotypical': 41225,
#  u'estimate': 14435,
#  u'gameplay': 16973,
#  u'chlorine': 7506,
#  u'silent': 39413,
#  u'husbands': 20125,
#  u'niammy': 29280,
#  u'disturbed': 12317,
#  u'esophagal': 14391,
#  u'purpose': 34522,
#  u'chromebooks': 7602,
#  u'megabytes': 26738,
#  u'feldspar': 15493,
#  u'beidou': 4125,
#  u'bilzerian': 4570,
#  u'olds': 30234,
#  u'bakelite': 3546,
#  u'renovated': 36169,
#  u'forrester': 16378,
#  u'needed': 28992,
#  u'master': 26344,
#  u'predecessors': 33516,
#  u'lifesciences': 24761,
#  u'genesis': 17263,
#  u'caitlyn': 6152,
#  u'rewards': 36667,
#  u'zeroth': 48468,
#  u'scraper': 38189,
#  u'positively': 33220,
#  u'ahmed': 957,
#  u'duckworth': 12977,
#  u'shampoos': 38860,
#  u'feeling': 15482,
#  u'vnit': 46690,
#  u'yeezys': 48227,
#  u'dolan': 12507,
#  u'plagarism': 32665,
#  u'kuamari': 23855,
#  u'mishra': 27497,
#  u'affairs': 784,
#  u'wholesome': 47491,
#  u'hymen': 20206,
#  u'paramedics': 31337,
#  u'rhce': 36697,
#  u'bhaang': 4370,
#  u'vga': 46352,
#  u'vgc': 46353,
#  u'kremlin': 23804,
#  u'vgs': 46355,
#  u'shipments': 39068,
#  u'diminishing': 11900,
#  u'cinematic': 7698,
#  u'simplify': 39474,
#  u'icloud': 20380,
#  u'kaali': 22934,
#  u'thaad': 43303,
#  u'vertices': 46318,
#  u'ragnarok': 34994,
#  u'tech': 42932,
#  u'prevention': 33728,
#  u'expectorants': 14864,
#  u'saying': 37926,
#  u'braising': 5421,
#  u'padded': 31057,
#  u'andolan': 1725,
#  u'tempted': 43086,
#  u'vindictive': 46506,
#  u'clicked': 7948,
#  u'kinase': 23487,
#  u'lube': 25373,
#  u'plate': 32728,
#  u'iata': 20317,
#  u'terrorising': 43199,
#  u'photoelectric': 32345,
#  u'altogether': 1418,
#  u'ldl': 24357,
#  u'levered': 24628,
#  u'jaguar': 22324,
#  u'seuss': 38724,
#  u'nicely': 29292,
#  u'patch': 31569,
#  u'openly': 30397,
#  u'programmatic': 33975,
#  u'heirloom': 19133,
#  u'pmfby': 32860,
#  u'counries': 9593,
#  u'profoundly': 33965,
#  u'tyndall': 44897,
#  u'lots': 25286,
#  u'lotr': 25285,
#  u'irr': 22034,
#  u'irs': 22057,
#  u'xvi': 48136,
#  u'irl': 22015,
#  u'irm': 22016,
#  u'irn': 22018,
#  u'srinivas': 40889,
#  u'conductive': 8853,
#  u'irc': 22005,
#  u'solenoid': 40214,
#  u'requisites': 36324,
#  u'wage': 46874,
#  u'natura': 28848,
#  u'extend': 14978,
#  u'nature': 28858,
#  u'fruits': 16696,
#  u'dynastic': 13145,
#  u'extent': 14987,
#  u'tendons': 43110,
#  u'diarrea': 11711,
#  u'anaemia': 1638,
#  u'fearlessly': 15431,
#  u'libyan': 24715,
#  u'fondles': 16227,
#  u'bloggers': 4899,
#  u'fondled': 16226,
#  u'minuses': 27427,
#  u'affiliated': 798,
#  u'brindle': 5596,
#  u'humming': 20061,
#  u'smackdown': 39910,
#  u'fri': 16612,
#  u'fro': 16663,
#  u'frm': 16661,
#  u'bothers': 5264,
#  u'much': 28296,
#  u'teewe': 42982,
#  u'fry': 16706,
#  u'toning': 43927,
#  u'obese': 29948,
#  u'spit': 40685,
#  u'hepa': 19218,
#  u'doubts': 12660,
#  u'cadburys': 6116,
#  u'spin': 40660,
#  u'professionally': 33937,
#  u'forwarder': 16401,
#  u'excersise': 14704,
#  u'moraines': 28003,
#  u'canoeing': 6364,
#  u'oclaro': 30082,
#  u'kohl': 23700,
#  u'conditioned': 8835,
#  u'subjectwise': 41665,
#  u'conditioner': 8836,
#  u'hone': 19716,
#  u'hong': 19726,
#  u'ignored': 20514,
#  u'honk': 19729,
#  u'democracies': 11158,
#  u'hons': 19742,
#  u'sterilized': 41231,
#  u'myocardial': 28572,
#  u'torpedoes': 44006,
#  u'mentors': 26880,
#  u'academic': 212,
#  u'academia': 211,
#  u'lonelier': 25197,
#  u'corporate': 9456,
#  u'massaging': 26335,
#  u'bellow': 4174,
#  u'appropriately': 2210,
#  u'antagonists': 1922,
#  u'psychometrics': 34330,
#  u'lassi': 24196,
#  u'noscript': 29626,
#  u'hai': 18527,
#  u'upsides': 45733,
#  u'hal': 18564,
#  u'ham': 18610,
#  u'han': 18641,
#  u'advancement': 676,
#  u'hay': 18941,
#  u'hap': 18722,
#  u'haq': 18748,
#  u'har': 18750,
#  u'hat': 18886,
#  u'hav': 18916,
#  u'haw': 18926,
#  u'freemyapps': 16558,
#  u'municipal': 28429,
#  u'elders': 13551,
#  u'pranks': 33449,
#  u'unequivocally': 45306,
#  u'churchofsatan': 7644,
#  u'indicative': 21061,
#  u'semi': 38515,
#  u'cogs': 8250,
#  u'lacroix': 23985,
#  u'mifi': 27233,
#  u'misdemeanors': 27482,
#  u'virality': 46544,
#  u'unabashedly': 45087,
#  u'defragmenter': 11023,
#  u'crowd': 10013,
#  u'crowe': 10022,
#  u'czech': 10398,
#  u'mosques': 28081,
#  u'crown': 10026,
#  u'deflection': 11015,
#  u'captive': 6451,
#  u'monsterusers': 27940,
#  u'bottom': 5276,
#  u'inhuman': 21322,
#  u'syphilis': 42476,
#  u'completly': 8673,
#  u'fyers': 16867,
#  u'starring': 41070,
#  u'caskets': 6668,
#  u'bamboo': 3627,
#  u'restlessness': 36465,
#  u'spaceships': 40448,
#  u'kotlin': 23764,
#  u'anomalous': 1888,
#  u'vonage': 46765,
#  u'dyson': 13156,
#  u'honeymoon': 19722,
#  u'marshals': 26246,
#  u'shoots': 39148,
#  u'despised': 11449,
#  u'fabric': 15097,
#  u'raped': 35201,
#  u'rapey': 35203,
#  u'grasping': 18024,
#  u'givewell': 17551,
#  u'rapes': 35202,
#  u'avocados': 3232,
#  u'perfumes': 31996,
#  u'distortions': 12287,
#  u'thesaurus': 43430,
#  u'idol': 20454,
#  u'nicest': 29294,
#  u'soldering': 40205,
#  u'prepration': 33625,
#  u'passenger': 31519,
#  u'disgrace': 12115,
#  u'barrymore': 3804,
#  u'bedsheet': 4051,
#  u'sympathy': 42424,
#  u'slideshare': 39830,
#  u'cambodia': 6248,
#  u'pasadena': 31504,
#  u'serverless': 38678,
#  u'palms': 31184,
#  u'smelling': 39945,
#  u'aragorn': 2290,
#  u'explosions': 14937,
#  u'hemiarthroplasty': 19189,
#  u'shootout': 39146,
#  u'hypoallergenic': 20266,
#  u'dayananda': 10657,
#  u'chail': 7074,
#  u'chain': 7075,
#  u'whoever': 47480,
#  u'chaid': 7073,
#  u'innerspring': 21382,
#  u'chair': 7081,
#  u'machu': 25568,
#  u'ballet': 3595,
#  u'amplification': 1600,
#  u'freelance': 16546,
#  u'rabinder': 34891,
#  u'megawatts': 26747,
#  u'lara': 24164,
#  u'connecting': 8977,
#  u'macho': 25567,
#  u'tenacious': 43090,
#  u'windshields': 47623,
#  u'paychecks': 31678,
#  u'jerk': 22538,
#  u'intake': 21576,
#  u'biopharmaceuticals': 4637,
#  u'gloomy': 17620,
#  u'klout': 23612,
#  u'rechargable': 35520,
#  u'goodrem': 17798,
#  u'exact': 14660,
#  u'aichi': 972,
#  u'minute': 27428,
#  u'skewed': 39673,
#  u'illustrators': 20634,
#  u'multiprocessing': 28394,
#  u'hindered': 19439,
#  u'copyrighted': 9400,
#  u'heavyweight': 19092,
#  u'chopping': 7553,
#  u'catelyn': 6743,
#  u'bagging': 3498,
#  u'celebrated': 6902,
#  u'baggins': 3499,
#  u'paradoxes': 31304,
#  u'geography': 17321,
#  u'celebrates': 6903,
#  u'unintentionally': 45405,
#  u'drafted': 12739,
#  u'oldies': 30233,
#  u'climbs': 7968,
#  u'honour': 19739,
#  u'vanderbilt': 46051,
#  u'apis': 2082,
#  u'address': 531,
#  u'dwindling': 13122,
#  u'benson': 4239,
#  u'impacted': 20733,
#  u'queue': 34782,
#  u'sprouted': 40811,
#  u'wavii': 47130,
#  u'influx': 21230,
#  u'proportion': 34102,
#  u'randoms': 35154,
#  u'undergone': 45222,
#  u'tayyibah': 42874,
#  u'handbags': 18648,
#  u'pints': 32561,
#  u'readability': 35377,
#  u'opposed': 30459,
#  u'etude': 14506,
#  u'dampness': 10502,
#  u'bimtech': 4574,
#  u'approving': 2220,
#  u'consoles': 9059,
#  u'wvm': 48009,
#  u'bharati': 4405,
#  u'bharath': 4404,
#  u'rebounding': 35471,
#  u'lowercase': 25328,
#  u'rutherford': 37401,
#  u'oscillator': 30670,
#  u'following': 16215,
#  u'osage': 30661,
#  u'groupme': 18207,
#  u'mailboxes': 25759,
#  u'camtasia': 6292,
#  u'listens': 24955,
#  u'litre': 24987,
#  u'thanking': 43322,
#  u'subroutines': 41704,
#  u'fueled': 16735,
#  u'laxative': 24302,
#  u'sociolinguistics': 40142,
#  u'vulkan': 46835,
#  u'insitute': 21461,
#  u'harmon': 18816,
#  u'denbury': 11211,
#  u'surfing': 42128,
#  u'sandeep': 37683,
#  u'quadrant': 34672,
#  u'skirmish': 39711,
#  u'impactful': 20734,
#  u'webpage': 47225,
#  u'professors': 33943,
#  u'structuring': 41541,
#  u'jig': 22602,
#  u'disconnect': 12054,
#  u'jio': 22629,
#  u'jim': 22611,
#  u'shibpur': 39025,
#  u'tulsidas': 44719,
#  u'jit': 22638,
#  u'jiu': 22643,
#  u'apron': 2237,
#  u'ezetimibe': 15085,
#  u'tigrinya': 43667,
#  u'mitacs': 27559,
#  u'nsf': 29761,
#  u'aprox': 2239,
#  u'sorted': 40368,
#  u'didi': 11756,
#  u'wedgie': 47249,
#  u'instability': 21483,
#  u'quarter': 34733,
#  u'quartet': 34739,
#  u'cornelius': 9438,
#  u'honduras': 19715,
#  u'bursting': 5984,
#  u'nsp': 29768,
#  u'entering': 14104,
#  u'kingsley': 23515,
#  u'salads': 37567,
#  u'disasters': 12016,
#  u'nominalism': 29521,
#  u'seriously': 38662,
#  u'topcoder': 43957,
#  u'incentives': 20918,
#  u'multivitamins': 28407,
#  u'snooker': 40059,
#  u'crazies': 9811,
#  u'grandma': 17983,
#  u'byte': 6083,
#  u'bootloader': 5187,
#  u'modest': 27714,
#  u'quibble': 34787,
#  u'hemorrhoids': 19201,
#  u'spoken': 40726,
#  u'spokeo': 40727,
#  u'parkinson': 31413,
#  u'spokes': 40728,
#  u'coalition': 8125,
#  u'fuelband': 16734,
#  u'someome': 40274,
#  u'lingering': 24884,
#  u'surgey': 42136,
#  u'ableton': 116,
#  u'surger': 42133,
#  u'snatch': 40028,
#  u'absorbs': 178,
#  u'hetchy': 19292,
#  u'crossroads': 10002,
#  u'rehab': 35912,
#  u'wandering': 46966,
#  u'bannig': 3698,
#  u'proactive': 33850,
#  u'turned': 44792,
#  u'chaudhary': 7272,
#  u'jewels': 22576,
#  u'uninterrupted': 45408,
#  u'turner': 44793,
#  u'borough': 5233,
#  u'zoe': 48524,
#  u'fashionable': 15317,
#  u'zoo': 48542,
#  u'pimple': 32521,
#  u'opposite': 30462,
#  u'discerning': 12032,
#  u'hackathons': 18494,
#  u'spirulina': 40684,
#  u'touchy': 44066,
#  u'jitters': 22642,
#  u'jerada': 22535,
#  u'obsidian': 30010,
#  u'wynk': 48020,
#  u'imagines': 20661,
#  u'friction': 16613,
#  u'inconsistent': 20968,
#  u'imagined': 20660,
#  u'recomended': 35570,
#  u'transact': 44222,
#  u'earaches': 13179,
#  u'decidual': 10829,
#  u'etcetera': 14454,
#  u'conures': 9266,
#  u'recombinant': 35568,
#  u'gerbils': 17350,
#  u'pimp': 32520,
#  u'tiki': 43670,
#  u'pima': 32518,
#  u'vohra': 46713,
#  u'hotness': 19875,
#  u'noisier': 29506,
#  u'breslin': 5528,
#  u'guterres': 18410,
#  u'stannis': 41037,
#  u'dexter': 11611,
#  u'masturbatory': 26369,
#  u'sponsorship': 40741,
#  u'vaccines': 45943,
#  u'kilometer': 23466,
#  u'nrsc': 29749,
#  u'moons': 27989,
#  u'exploration': 14929,
#  u'metacrawler': 26986,
#  u'sggs': 38786,
#  u'millionaire': 27324,
#  u'flipped': 16042,
#  u'workplace': 47854,
#  u'semitic': 38531,
#  u'grooming': 18178,
#  u'potstickers': 33317,
#  u'allowance': 1337,
#  u'rajaji': 35051,
#  u'messeges': 26968,
#  u'dameron': 10489,
#  u'edisha': 13362,
#  u'deliberatly': 11095,
#  u'collider': 8345,
#  u'collides': 8346,
#  u'vipassna': 46536,
#  u'west': 47346,
#  u'incubation': 20999,
#  u'motives': 28120,
#  u'vomits': 46763,
#  u'macromolecules': 25581,
#  u'libgdx': 24704,
#  u'photon': 32361,
#  u'readings': 35386,
#  u'photos': 32364,
#  u'yzf': 48393,
#  u'hashtag': 18871,
#  u'abject': 112,
#  u'iver': 22251,
#  u'unlikeable': 45458,
#  u'ichangemycity': 20371,
#  u'limping': 24856,
#  u'sriram': 40891,
#  u'hermaphrodite': 19251,
#  u'technology': 42958,
#  u'mpc': 28211,
#  u'verified': 46278,
#  u'verifier': 46279,
#  u'verifies': 46280,
#  u'otto': 30725,
#  u'visually': 46619,
#  u'assigns': 2733,
#  u'strawman': 41449,
#  u'advertisement': 701,
#  u'fimo': 15741,
#  u'weightage': 47285,
#  u'colorants': 8390,
#  u'homestays': 19678,
#  u'persistently': 32081,
#  u'planets': 32693,
#  u'generator': 17256,
#  u'mandolin': 25960,
#  u'saddened': 37473,
#  u'kaveri': 23184,
#  u'zion': 48498,
#  u'rejoin': 35969,
#  u'diphenhydramine': 11935,
#  u'decomposed': 10874,
#  u'sums': 41930,
#  u'sumo': 41929,
#  u'japanophile': 22410,
#  u'traffic': 44174,
#  u'preference': 33552,
#  u'enums': 14159,
#  u'decomposes': 10877,
#  u'decomposer': 10875,
#  u'sensational': 38565,
#  u'malfunctions': 25868,
#  u'superiority': 42017,
#  u'enery': 13980,
#  u'obstruct': 30018,
#  u'burpees': 5970,
#  u'seating': 38347,
#  u'bladeless': 4792,
#  u'rottweilers': 37176,
#  u'heidegger': 19119,
#  u'khwaja': 23410,
#  u'scottie': 38171,
#  u'transmutation': 44308,
#  u'flashgot': 15951,
#  u'averse': 3210,
#  u'disinformation': 12139,
#  u'meniscus': 26852,
#  u'disparaging': 12173,
#  u'thailand': 43307,
#  u'dyslexia': 13153,
#  u'ferromagnetic': 15567,
#  u'hopkins': 19782,
#  u'antidote': 1967,
#  u'hippocampi': 19470,
#  u'lively': 25009,
#  u'pivot': 32623,
#  u'sealer': 38315,
#  u'bubbli': 5776,
#  u'redirection': 35682,
#  u'celcon': 6899,
#  u'sealed': 38314,
#  u'brazilian': 5465,
#  u'bubble': 5774,
#  u'saris': 37794,
#  u'societal': 40136,
#  u'corvus': 9521,
#  u'sarif': 37793,
#  u'satbara': 37827,
#  u'abused': 198,
#  u'childen': 7431,
#  u'raga': 34981,
#  u'monopoly': 27913,
#  u'rags': 34996,
#  u'grapefruits': 18007,
#  u'dirty': 11978,
#  u'abuser': 199,
#  u'abuses': 201,
#  u'monopole': 27908,
#  u'trips': 44527,
#  u'munde': 28422,
#  u'creat': 9826,
#  u'watches': 47084,
#  u'watcher': 47083,
#  u'formulation': 16373,
#  u'watched': 47082,
#  u'tremble': 44410,
#  u'cream': 9819,
#  u'yoga': 48297,
#  u'bored': 5214,
#  u'yogi': 48301,
#  u'ascertained': 2587,
#  u'unwelcomed': 45647,
#  u'hofstra': 19594,
#  u'unparalleled': 45503,
#  u'reamma': 35429,
#  u'circumsized': 7734,
#  u'refunded': 35821,
#  u'waving': 47131,
#  u'brotherhood': 5690,
#  u'ulhasnagar': 45039,
#  u'tricky': 44469,
#  u'natalie': 28814,
#  u'ghosting': 17436,
#  u'tricks': 44468,
#  u'ucms': 44963,
#  u'legislatures': 24488,
#  u'senna': 38561,
#  u'caused': 6783,
#  u'ceramic': 6997,
#  u'acknowledging': 372,
#  u'puneri': 34457,
#  u'bismarck': 4701,
#  u'riots': 36854,
#  u'glycol': 17654,
#  u'norm': 29589,
#  u'wayfarers': 47141,
#  u'floated': 16055,
#  u'floater': 16056,
#  u'expats': 14854,
#  u'sant': 37738,
#  u'linguists': 24891,
#  u'sans': 37734,
#  u'sang': 37704,
#  u'sand': 37677,
#  u'sane': 37703,
#  u'sank': 37727,
#  u'sani': 37715,
#  u'abbreviated': 67,
#  u'harsha': 18838,
#  u'dhabas': 11632,
#  u'crosswalks': 10003,
#  u'accreditation': 296,
#  u'ladakh': 23996,
#  u'prevailed': 33717,
#  u'forign': 16339,
#  u'leia': 24506,
#  u'hebei': 19095,
#  u'hash': 18859,
#  u'fipb': 15816,
#  u'portrays': 33197,
#  u'vacations': 45938,
#  u'hast': 18880,
#  u'tubeless': 44684,
#  u'criminality': 9903,
#  u'byu': 6087,
#  u'pyrolysis': 34607,
#  u'fastenal': 15326,
#  u'periodic': 32006,
#  u'provable': 34215,
#  u'skepticism': 39665,
#  u'luck': 25390,
#  u'habra': 18489,
#  u'depart': 11269,
#  u'reclaimed': 35549,
#  u'ilets': 20596,
#  u'traumatized': 44353,
#  u'mohandas': 27760,
#  u'dreamspark': 12804,
#  u'silva': 39433,
#  u'vlsi': 46675,
#  u'mort': 28056,
#  u'odometer': 30124,
#  u'automata': 3133,
#  u'automate': 3134,
#  u'mora': 28001,
#  u'helps': 19178,
#  u'initiated': 21335,
#  u'company': 8600,
#  u'corrected': 9467,
#  u'initiates': 21336,
#  u'lameness': 24070,
#  u'leary': 24407,
#  u'aricent': 2395,
#  u'installing': 21499,
#  u'eusocial': 14556,
#  u'learn': 24396,
#  u'knocked': 23653,
#  u'scramble': 38183,
#  u'barclay': 3748,
#  u'allegra': 1288,
#  u'civilizations': 7786,
#  u'meaner': 26614,
#  u'allegro': 1289,
#  u'lesotho': 24588,
#  u'vasocongestion': 46126,
#  u'bonded': 5108,
#  u'huge': 20006,
#  u'hugo': 20012,
#  u'hugh': 20010,
#  u'dismissed': 12158,
#  u'scifi': 38120,
#  u'hugs': 20013,
#  u'dismisses': 12159,
#  u'higley': 19393,
#  u'dentures': 11256,
#  u'thickened': 43444,
#  u'brett': 5532,
#  u'bioinformatics': 4617,
#  u'tulane': 44710,
#  u'resemble': 36347,
#  u'twisting': 44873,
#  u'cigarets': 7672,
#  u'installed': 21496,
#  u'stylus': 41622,
#  u'paper': 31274,
#  u'scott': 38170,
#  u'installer': 21497,
#  u'turbocharge': 44765,
#  u'xiaoping': 48079,
#  u'bendix': 4201,
#  u'bypass': 6075,
#  u'isaac': 22065,
#  u'sauce': 37863,
#  u'reintroduced': 35950,
#  u'colleague': 8323,
#  u'abandons': 51,
#  u'gadget': 16891,
#  u'susano': 42190,
#  u'frizzy': 16660,
#  u'idols': 20459,
#  u'document': 12455,
#  u'autocracy': 3115,
#  u'everytime': 14623,
#  u'courses': 9653,
#  u'shocking': 39121,
#  u'chipping': 7478,
#  u'stargaze': 41060,
#  u'begged': 4083,
#  u'arashi': 2302,
#  u'lipstick': 24924,
#  u'ernie': 14325,
#  u'relaxers': 36001,
#  u'research': 36335,
#  u'atwater': 2983,
#  u'offline': 30172,
#  u'electricals': 13575,
#  u'terra': 43174,
#  u'influencial': 21226,
#  u'airway': 1059,
#  u'ecologically': 13300,
#  u'offsite': 30180,
#  u'roopkund': 37108,
#  u'hyderabad': 20158,
#  u'licencing': 24722,
#  u'traicionar': 44183,
#  u'preservation': 33658,
#  u'cebinae': 6883,
#  u'saina': 37545,
#  u'swipe': 42351,
#  u'adenovirus': 547,
#  u'saint': 37548,
#  u'essays': 14411,
#  u'purer': 34502,
#  u'cheekbones': 7316,
#  u'sbbj': 37932,
#  u'syringes': 42483,
#  u'persuing': 32109,
#  u'getaway': 17379,
#  u'unwaiveringly': 45642,
#  u'emirates': 13790,
#  u'toyboy': 44116,
#  u'organisations': 30573,
#  u'swanky': 42266,
#  u'guarding': 18292,
#  u'blond': 4904,
#  u'conjugate': 8960,
#  u'odors': 30128,
#  u'fermented': 15544,
#  u'employable': 13842,
#  u'recognizing': 35564,
#  u'baluchistan': 3623,
#  u'butterflies': 6030,
#  u'pringles': 33790,
#  u'diatomic': 11722,
#  u'singles': 39530,
#  u'singlet': 39531,
#  u'experince': 14896,
#  u'understands': 45248,
#  u'seize': 38465,
#  u'fiscally': 15854,
#  u'stoning': 41348,
#  u'cultivating': 10170,
#  u'wording': 47821,
#  u'exterminate': 14990,
#  u'blended': 4844,
#  u'affix': 809,
#  u'accommodations': 269,
#  u'naomi': 28740,
#  u'overwhelmed': 30949,
#  u'blender': 4845,
#  u'chakravyuh': 7091,
#  u'gooey': 17806,
#  u'bipc': 4660,
#  u'removable': 36117,
#  u'indifference': 21072,
#  u'columns': 8416,
#  u'chiefdoms': 7417,
#  u'uncontested': 45179,
#  u'secular': 38388,
#  u'remedy': 36083,
#  u'compass': 8619,
#  u'distraction': 12292,
#  u'sects': 38386,
#  u'pleasures': 32791,
#  u'bracings': 5374,
#  u'seperated': 38613,
#  u'oceaneering': 30069,
#  u'rumored': 37338,
#  u'minoxidil': 27420,
#  u'flyrig': 16148,
#  u'activists': 443,
#  u'collectively': 8333,
#  u'analog': 1650,
#  u'personification': 32097,
#  u'deactivate': 10714,
#  u'dipole': 11945,
#  u'thrive': 43547,
#  u'struct': 41534,
#  u'empowering': 13853,
#  u'legitimately': 24492,
#  u'aipgmee': 1005,
#  u'retarded': 36523,
#  u'bell': 4160,
#  u'iphones': 21970,
#  u'firewalling': 15837,
#  u'adaptation': 487,
#  u'eva': 14563,
#  u'belt': 4186,
#  u'satire': 37837,
#  u'suburbs': 41774,
#  u'proprietor': 34118,
#  u'initiation': 21338,
#  u'faulkner': 15368,
#  u'nri': 29745,
#  u'nro': 29748,
#  u'counselling': 9597,
#  u'nrc': 29740,
#  u'nra': 29739,
#  u'kerberos': 23294,
#  u'nrg': 29744,
#  u'nrf': 29743,
#  u'nre': 29741,
#  u'adaptable': 486,
#  u'awake': 3254,
#  u'pacemaker': 31024,
#  u'consulate': 9120,
#  u'nrt': 29750,
#  u'presses': 33676,
#  u'budget': 5806,
#  u'pressed': 33674,
#  u'nucleotides': 29801,
#  u'wooplr': 47814,
#  u'sabha': 37441,
#  u'agitation': 908,
#  u'averaging': 3208,
#  u'binding': 4581,
#  u'accure': 310,
#  u'hydrocodone': 20176,
#  u'gastroenterologist': 17093,
#  u'raiders': 35011,
#  u'weekday': 47260,
#  u'geeta': 17207,
#  u'faught': 15366,
#  u'gnwl': 17687,
#  u'nickname': 29306,
#  u'infamous': 21160,
#  u'knn': 23649,
#  u'mathikere': 26410,
#  u'shortfeeds': 39187,
#  u'knw': 23679,
#  u'courting': 9659,
#  u'vgg': 46354,
#  u'politely': 32995,
#  u'hercules': 19237,
#  u'tin': 43723,
#  ...}

# %%
def sklearn_tfidf_word_match_share(row):
    q1words = {}
    q2words = {}
    for word in str(row['question1']).lower().split():
        if word not in stops:
            q1words[word] = 1
    for word in str(row['question2']).lower().split():
        if word not in stops:
            q2words[word] = 1
    if len(q1words) == 0 or len(q2words) == 0:
        return 0
    
    shared_weights = [sk_weights.get(w, 0) for w in q1words.keys() if w in q2words] \
                   + [sk_weights.get(w, 0) for w in q2words.keys() if w in q1words]
    total_weights = [sk_weights.get(w, 0) for w in q1words] + \
                    [sk_weights.get(w, 0) for w in q2words]
    
    try:
        R = 1.00000 * np.sum(shared_weights) / np.sum(total_weights)
    except ZeroDivisionError:
        R = 0
    
    return R

# %%
sk_tfidf_train_word_match = df_train.apply(sklearn_tfidf_word_match_share, axis=1, raw=True)
sk_tfidf_train_word_match
# Out:
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:17: RuntimeWarning: invalid value encountered in double_scalars
# 0         0.901830
# 1         0.191605
# 2         0.519395
# 3         0.000000
# 4         0.000000
# 5         0.602577
# 6         0.000000
# 7         0.000000
# 8         1.000000
# 9         0.796954
# 10        0.000000
# 11        0.519143
# 12        1.000000
# 13        0.880059
# 14        1.000000
# 15        0.478724
# 16        1.000000
# 17        0.000000
# 18        0.431667
# 19        0.662909
# 20        0.546081
# 21        0.000000
# 22        0.070463
# 23        0.000000
# 24        0.000000
# 25        0.947420
# 26        0.977579
# 27        0.000000
# 28        0.847898
# 29        0.639023
#             ...
# 404260    0.923715
# 404261    0.831325
# 404262    0.521105
# 404263    0.287301
# 404264    0.497948
# 404265    0.358458
# 404266    0.239410
# 404267    0.775304
# 404268    0.000000
# 404269    0.567428
# 404270    1.000000
# 404271    0.000000
# 404272    0.356448
# 404273    0.451996
# 404274    0.408700
# 404275    0.000000
# 404276         NaN
# 404277    0.000000
# 404278    0.527884
# 404279    0.182764
# 404280    0.841192
# 404281    0.831375
# 404282    0.510091
# 404283    0.198969
# 404284    0.875456
# 404285    0.797451
# 404286    0.503853
# 404287    0.000000
# 404288    0.000000
# 404289    1.000000
# dtype: float64

# %%
# plt.figure(figsize=(15, 5))
# plt.hist(sk_tfidf_train_word_match[df_train['is_duplicate'] == 0].fillna(0), bins=20, normed=True, label='Not Duplicate')
# plt.hist(sk_tfidf_train_word_match[df_train['is_duplicate'] == 1].fillna(0), bins=20, normed=True, alpha=0.7, label='Duplicate')
# plt.legend()
# plt.title('Label distribution over SKLEARN tfidf_word_match_share', fontsize=15)
# plt.xlabel('word_match_share', fontsize=15)

# %%
from sklearn.metrics import roc_auc_score
print('Original AUC:', roc_auc_score(df_train['is_duplicate'], train_word_match))
print('   TFIDF AUC:', roc_auc_score(df_train['is_duplicate'], tfidf_train_word_match.fillna(0)))
print('SKLEARN TFIDF AUC:', roc_auc_score(df_train['is_duplicate'], sk_tfidf_train_word_match.fillna(0)))
# Out:
# ('Original AUC:', 0.78055320062812139)
# ('   TFIDF AUC:', 0.77056665661851498)
# ('SKLEARN TFIDF AUC:', 0.70689963913038989)

# %% [markdown]
# # Rebalance the data.

# %%
# First we create our training and testing data
x_train = pd.DataFrame()
x_test = pd.DataFrame()

x_train['word_match'] = train_word_match
# x_train['tfidf_word_match'] = tfidf_train_word_match
# x_train['sk_tfidf_word_match'] = sk_tfidf_train_word_match

x_test['word_match'] = df_test.apply(word_match_share, axis=1, raw=True)
# x_test['tfidf_word_match'] = df_test.apply(tfidf_word_match_share, axis=1, raw=True)
# x_test['sk_tfidf_word_match'] = df_test.apply(sklearn_tfidf_word_match_share, axis=1, raw=True)

y_train = df_train['is_duplicate'].values

# %%
pos_train = x_train[y_train == 1]
neg_train = x_train[y_train == 0]

# Now we oversample the negative class
# There is likely a much more elegant way to do this...
p = 0.165
scale = ((len(pos_train) / (len(pos_train) + len(neg_train))) / p) - 1
while scale > 1:
    neg_train = pd.concat([neg_train, neg_train])
    scale -= 1
print('scale: ', scale, ', len(neg_train): ', len(neg_train))
neg_train = pd.concat([neg_train, neg_train[:int(scale * len(neg_train))]])
print(len(pos_train) / (len(pos_train) + len(neg_train)))

x_train = pd.concat([pos_train, neg_train])
y_train = (np.zeros(len(pos_train)) + 1).tolist() + np.zeros(len(neg_train)).tolist()
del pos_train, neg_train
# Out:
# ('scale: ', -1.0, ', len(neg_train): ', 255027)
# 0

# %% [markdown]
# # Train / Validation Split

# %%
# Finally, we split some of the data off for validation
from sklearn.model_selection import train_test_split

x_train, x_valid, y_train, y_valid = \
    train_test_split(x_train, y_train, test_size=0.2, random_state=4242)

# %% [markdown]
# # Using only shared word feature

# %%
import xgboost as xgb

# Set our parameters for xgboost
# params = {}
# params['objective'] = 'binary:logistic'
# params['eval_metric'] = 'logloss'
# params['eta'] = 0.02
# params['max_depth'] = 4

# d_train = xgb.DMatrix(x_train, label=y_train)
# d_valid = xgb.DMatrix(x_valid, label=y_valid)

# watchlist = [(d_train, 'train'), (d_valid, 'valid')]

# bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=50, verbose_eval=10)

# %% [markdown]
# # Using shared word + custom tf-idf features + sklearn tf-idf features

# %%
import time

time_start = time.time()
### Step 1: Create dataframe with desired features ###
# First we create our training and testing data
x_train = pd.DataFrame()
x_test = pd.DataFrame()

x_train['word_match'] = train_word_match
x_train['tfidf_word_match'] = tfidf_train_word_match
x_train['sk_tfidf_word_match'] = sk_tfidf_train_word_match

x_test['word_match'] = df_test.apply(word_match_share, axis=1, raw=True)
x_test['tfidf_word_match'] = df_test.apply(tfidf_word_match_share, axis=1, raw=True)
x_test['sk_tfidf_word_match'] = df_test.apply(sklearn_tfidf_word_match_share, axis=1, raw=True)

y_train = df_train['is_duplicate'].values

### Step 2: Re-balance the data ###
pos_train = x_train[y_train == 1]
neg_train = x_train[y_train == 0]

# Now we oversample the negative class
# There is likely a much more elegant way to do this...
p = 0.165
scale = ((len(pos_train) / (len(pos_train) + len(neg_train))) / p) - 1
while scale > 1:
    neg_train = pd.concat([neg_train, neg_train])
    scale -= 1
print('scale: ', scale, ', len(neg_train): ', len(neg_train))
neg_train = pd.concat([neg_train, neg_train[:int(scale * len(neg_train))]])
print(len(pos_train) / (len(pos_train) + len(neg_train)))

x_train = pd.concat([pos_train, neg_train])
y_train = (np.zeros(len(pos_train)) + 1).tolist() + np.zeros(len(neg_train)).tolist()
del pos_train, neg_train

### Step 3: train/validation split ###
# Finally, we split some of the data off for validation
x_train, x_valid, y_train, y_valid = \
    train_test_split(x_train, y_train, test_size=0.2, random_state=4242)
    
### Step 4: xgb training ###
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.02
params['max_depth'] = 4

d_train = xgb.DMatrix(x_train, label=y_train)
d_valid = xgb.DMatrix(x_valid, label=y_valid)

watchlist = [(d_train, 'train'), (d_valid, 'valid')]

# bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=50, verbose_eval=10)

time_end = time.time()
print 'Total time: ', time_end - time_start
# Out:
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:18: RuntimeWarning: invalid value encountered in double_scalars
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:17: RuntimeWarning: invalid value encountered in double_scalars
# ('scale: ', -1.0, ', len(neg_train): ', 255027)
# 0
# Total time:  471.25956583

# %%
x_train.head()
# Out:
#         word_match  tfidf_word_match  sk_tfidf_word_match
# 107566    1.000000          1.000000             1.000000
# 150920    0.727273          0.768967             0.450285
# 335233    0.400000          0.395250             0.413189
# 302735    0.352941          0.342702             0.348979
# 363023    0.285714          0.302993             0.654963

# %% [markdown]
# # Tuned xgb params by David Solis

# %%
# %time

params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.11
params['max_depth'] = 5

d_train = xgb.DMatrix(x_train, label=y_train)
d_valid = xgb.DMatrix(x_valid, label=y_valid)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 4.05 µs

# %% [markdown]
# # Use cross validation to check the performance.

# %%
time_start = time.time()

model_cv = xgb.cv(params, \
                  d_train, \
                  1000, \
                  nfold=3, \
                  metrics='logloss', \
                  early_stopping_rounds=50, \
                  verbose_eval=10)

time_end = time.time()
print 'Total time: ', time_end - time_start
# Out:
# [0]	train-logloss:0.655546+9.16564e-05	test-logloss:0.655588+7.95669e-05
# [10]	train-logloss:0.501523+0.000375022	test-logloss:0.501969+0.000627083
# [20]	train-logloss:0.466685+0.000509379	test-logloss:0.467398+0.000852321
# [30]	train-logloss:0.456429+0.000514036	test-logloss:0.457432+0.000991269
# [40]	train-logloss:0.452643+0.000453545	test-logloss:0.453958+0.0011722
# [50]	train-logloss:0.450809+0.000455576	test-logloss:0.452421+0.0012436
# [60]	train-logloss:0.449627+0.000411023	test-logloss:0.451569+0.00126667
# [70]	train-logloss:0.448591+0.000435667	test-logloss:0.450909+0.0012406
# [80]	train-logloss:0.447511+0.000427763	test-logloss:0.450256+0.0012611
# [90]	train-logloss:0.446618+0.000526098	test-logloss:0.449821+0.00116435
# [100]	train-logloss:0.445836+0.000397332	test-logloss:0.44947+0.00128567
# [110]	train-logloss:0.445158+0.00040465	test-logloss:0.449212+0.00127225
# [120]	train-logloss:0.444465+0.000468584	test-logloss:0.448885+0.00123871
# [130]	train-logloss:0.443831+0.000385489	test-logloss:0.448634+0.00128631
# [140]	train-logloss:0.443289+0.000311116	test-logloss:0.448483+0.00134742
# [150]	train-logloss:0.442735+0.00044875	test-logloss:0.448324+0.00125741
# [160]	train-logloss:0.44221+0.000483246	test-logloss:0.448183+0.00128109
# [170]	train-logloss:0.441684+0.000481125	test-logloss:0.448044+0.00129911
# [180]	train-logloss:0.44116+0.000362699	test-logloss:0.447907+0.00136929
# [190]	train-logloss:0.440804+0.000421908	test-logloss:0.447858+0.00137475
# [200]	train-logloss:0.440344+0.000455296	test-logloss:0.447778+0.00133858
# [210]	train-logloss:0.439938+0.000495131	test-logloss:0.447743+0.00131696
# [220]	train-logloss:0.43949+0.000501965	test-logloss:0.447631+0.00129383
# [230]	train-logloss:0.439083+0.00046306	test-logloss:0.447551+0.0013039
# [240]	train-logloss:0.438708+0.000441684	test-logloss:0.447522+0.00132656
# [250]	train-logloss:0.438307+0.000502304	test-logloss:0.447463+0.00128065
# [260]	train-logloss:0.437903+0.000425783	test-logloss:0.447412+0.00130391
# [270]	train-logloss:0.437538+0.000462212	test-logloss:0.447359+0.00129102
# [280]	train-logloss:0.437116+0.000474308	test-logloss:0.447294+0.00126227
# [290]	train-logloss:0.436772+0.000452737	test-logloss:0.447278+0.00127715
# [300]	train-logloss:0.436422+0.000505169	test-logloss:0.447218+0.00125446
# [310]	train-logloss:0.436084+0.000511214	test-logloss:0.44719+0.00121983
# [320]	train-logloss:0.435717+0.000514425	test-logloss:0.447179+0.00120856
# [330]	train-logloss:0.435294+0.000501331	test-logloss:0.447125+0.00120377
# [340]	train-logloss:0.434933+0.000516058	test-logloss:0.447092+0.00118094
# [350]	train-logloss:0.434618+0.00056045	test-logloss:0.447069+0.00116127
# [360]	train-logloss:0.434345+0.000592666	test-logloss:0.44707+0.00114892
# [370]	train-logloss:0.434077+0.000591172	test-logloss:0.447076+0.00113854
# [380]	train-logloss:0.433745+0.000593433	test-logloss:0.447074+0.00114422
# [390]	train-logloss:0.433394+0.000611755	test-logloss:0.447052+0.00113876
# [400]	train-logloss:0.433123+0.000676435	test-logloss:0.447043+0.00110514
# [410]	train-logloss:0.432748+0.00061738	test-logloss:0.446998+0.00111184
# [420]	train-logloss:0.432432+0.000569998	test-logloss:0.446955+0.00117325
# [430]	train-logloss:0.432133+0.000535382	test-logloss:0.44694+0.00119458
# [440]	train-logloss:0.431748+0.000548941	test-logloss:0.44689+0.00121001
# [450]	train-logloss:0.431426+0.000531075	test-logloss:0.446884+0.00120397
# [460]	train-logloss:0.431087+0.00049666	test-logloss:0.446889+0.00119017
# [470]	train-logloss:0.430836+0.000529688	test-logloss:0.446896+0.00116923
# [480]	train-logloss:0.430572+0.000538285	test-logloss:0.446918+0.00117629
# [490]	train-logloss:0.430244+0.000493407	test-logloss:0.446933+0.00118063
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 4.05 µs

# %%
plt.figure(figsize=(10,8))
plt.plot(model_cv['train-logloss-mean'], label='training')
plt.plot(model_cv['test-logloss-mean'], label='validation')
# plt.xlim(200, 400)
# plt.ylim(0.3, 0.38)
plt.xlabel('num. of rounds')
plt.ylabel('Log Loss Error')
plt.legend()
plt.show()

# %%
time_start = time.time()

watchlist = [(d_train, 'train'), (d_valid, 'valid')]
bst = xgb.train(params, d_train, 1000, watchlist, early_stopping_rounds=50, verbose_eval=10)

time_end = time.time()
print 'Total time: ', time_end - time_start
# Out:
# [0]	train-logloss:0.655566	valid-logloss:0.655475
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# [10]	train-logloss:0.501699	valid-logloss:0.501203
# [20]	train-logloss:0.466841	valid-logloss:0.466263
# [30]	train-logloss:0.456705	valid-logloss:0.456226
# [40]	train-logloss:0.452888	valid-logloss:0.452515
# [50]	train-logloss:0.451053	valid-logloss:0.45085
# [60]	train-logloss:0.449949	valid-logloss:0.449916
# [70]	train-logloss:0.448775	valid-logloss:0.449018
# [80]	train-logloss:0.447898	valid-logloss:0.448412
# [90]	train-logloss:0.446906	valid-logloss:0.447748
# [100]	train-logloss:0.446071	valid-logloss:0.447209
# [110]	train-logloss:0.445359	valid-logloss:0.446785
# [120]	train-logloss:0.444826	valid-logloss:0.44653
# [130]	train-logloss:0.44438	valid-logloss:0.446456
# [140]	train-logloss:0.443836	valid-logloss:0.446159
# [150]	train-logloss:0.443387	valid-logloss:0.445942
# [160]	train-logloss:0.442834	valid-logloss:0.445639
# [170]	train-logloss:0.442471	valid-logloss:0.445552
# [180]	train-logloss:0.44208	valid-logloss:0.445401
# [190]	train-logloss:0.44172	valid-logloss:0.445326
# [200]	train-logloss:0.441382	valid-logloss:0.445285
# [210]	train-logloss:0.441051	valid-logloss:0.445177
# [220]	train-logloss:0.440724	valid-logloss:0.445114
# [230]	train-logloss:0.440443	valid-logloss:0.44507
# [240]	train-logloss:0.440146	valid-logloss:0.44501
# [250]	train-logloss:0.439859	valid-logloss:0.444982
# [260]	train-logloss:0.43953	valid-logloss:0.444889
# [270]	train-logloss:0.439161	valid-logloss:0.444768
# [280]	train-logloss:0.438884	valid-logloss:0.444716
# [290]	train-logloss:0.438491	valid-logloss:0.444544
# [300]	train-logloss:0.438305	valid-logloss:0.444523
# [310]	train-logloss:0.438039	valid-logloss:0.444492
# [320]	train-logloss:0.437765	valid-logloss:0.444393
# [330]	train-logloss:0.437446	valid-logloss:0.444294
# [340]	train-logloss:0.437252	valid-logloss:0.444279
# [350]	train-logloss:0.436921	valid-logloss:0.444147
# [360]	train-logloss:0.436661	valid-logloss:0.4441
# [370]	train-logloss:0.436387	valid-logloss:0.444058
# [380]	train-logloss:0.436122	valid-logloss:0.444043
# [390]	train-logloss:0.435845	valid-logloss:0.443975
# Total time:  41.0167970657

# %%
# %timeit

model_val = bst.predict(xgb.DMatrix(x_valid))
model_val
# Out:
# array([  6.05960846e-01,   2.74615391e-04,   3.85629217e-04, ...,
#          6.06557012e-01,   6.15855277e-01,   5.42998374e-01], dtype=float32)

# %%
from sklearn.metrics import log_loss

print((model_val))
print((np.array(y_valid)))
log_loss(np.array(y_valid), model_val)
# Out:
# [  6.05960846e-01   2.74615391e-04   3.85629217e-04 ...,   6.06557012e-01
#    6.15855277e-01   5.42998374e-01]
# [ 0.  0.  0. ...,  1.  0.  1.]
# 0.44390154493655259

# %%
model_test = bst.predict(xgb.DMatrix(x_test))

submission = pd.DataFrame()
submission['test_id'] = df_test['test_id']
submission['is_duplicate'] = model_test
submission.to_csv('simple_xgb.csv', index=False)

# %%
submission.head()
# Out:
#    test_id  is_duplicate
# 0        0      0.429014
# 1        1      0.429014
# 2        2      0.429014
# 3        3      0.001440
# 4        4      0.367386
